# %%
# !pip install neo4j yfiles_jupyter_graphs_for_neo4j
# !pip install pyspark
# Out:
# Collecting neo4j
#   Downloading neo4j-5.28.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting yfiles_jupyter_graphs_for_neo4j
#   Downloading yfiles_jupyter_graphs_for_neo4j-1.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from neo4j) (2025.1)
# Collecting yfiles_jupyter_graphs>=1.9.0 (from yfiles_jupyter_graphs_for_neo4j)
#   Downloading yfiles_jupyter_graphs-1.10.1-py3-none-any.whl.metadata (19 kB)
# Collecting ipywidgets>=8.0.0 (from yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (5.7.1)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (3.0.13)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.0->yfiles_jupyter_graphs>=1.9.0->yfiles_jupyter_graphs_for_neo4j) (0.2.13)
# Downloading neo4j-5.28.1-py3-none-any.whl (312 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 312.3/312.3 kB 4.9 MB/s eta 0:00:00
# Downloading yfiles_jupyter_graphs_for_neo4j-1.6.0-py3-none-any.whl (13 kB)
# Downloading yfiles_jupyter_graphs-1.10.1-py3-none-any.whl (15.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 83.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 12.7 MB/s eta 0:00:00
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 77.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 60.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, neo4j, jedi, comm, ipywidgets, yfiles_jupyter_graphs, yfiles_jupyter_graphs_for_neo4j
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed comm-0.2.2 ipywidgets-8.1.5 jedi-0.19.2 neo4j-5.28.1 widgetsnbextension-4.0.13 yfiles_jupyter_graphs-1.10.1 yfiles_jupyter_graphs_for_neo4j-1.6.0
# Requirement already satisfied: pyspark in /usr/local/lib/python3.11/dist-packages (3.5.5)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.11/dist-packages (from pyspark) (0.10.9.7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType, FloatType

# Initializing Spark session
spark = SparkSession.builder \
    .appName("Loading Data") \
    .config("spark.driver.memory", "12g") \
    .config("spark.executor.memory", "12g") \
    .getOrCreate()

# %%
# Schema Definition
sub_schema = StructType([
    StructField("adsh", StringType(), nullable=False),
    StructField("cik", StringType(), nullable=False),
    StructField("name", StringType(), nullable=False),
    StructField("sic", StringType(), nullable=True),
    StructField("countryba", StringType(), nullable=True),
    StructField("stprba", StringType(), nullable=True),
    StructField("cityba", StringType(), nullable=True),
    StructField("zipba", StringType(), nullable=True),
    StructField("bas1", StringType(), nullable=True),
    StructField("bas2", StringType(), nullable=True),
    StructField("baph", StringType(), nullable=True),
    StructField("countryma", StringType(), nullable=True),
    StructField("stprma", StringType(), nullable=True),
    StructField("cityma", StringType(), nullable=True),
    StructField("zipma", StringType(), nullable=True),
    StructField("mas1", StringType(), nullable=True),
    StructField("mas2", StringType(), nullable=True),
    StructField("countryinc", StringType(), nullable=True),
    StructField("stprinc", StringType(), nullable=True),
    StructField("ein", StringType(), nullable=True),
    StructField("former", StringType(), nullable=True),
    StructField("changed", StringType(), nullable=True),
    StructField("afs", StringType(), nullable=True),
    StructField("wksi", StringType(), nullable=False),
    StructField("fye", StringType(), nullable=True),
    StructField("form", StringType(), nullable=False),
    StructField("period", StringType(), nullable=False),
    StructField("fy", StringType(), nullable=True),
    StructField("fp", StringType(), nullable=True),
    StructField("filed", StringType(), nullable=False),
    StructField("accepted", StringType(), nullable=False),
    StructField("prevrpt", StringType(), nullable=False),
    StructField("detail", StringType(), nullable=False),
    StructField("instance", StringType(), nullable=False),
    StructField("nciks", StringType(), nullable=False),
    StructField("aciks", StringType(), nullable=True)])

# Function to load data for a specific quarter
def load_sub_data(quarter):
    sub_df = spark.read.option("delimiter", "\t") \
        .schema(sub_schema) \
        .csv(f"/content/drive/Shareddrives/DATS6450-Project2/{quarter}/sub.txt")

    sub_df = sub_df.replace("", None)
    sub_df = sub_df.filter(sub_df.adsh != sub_df.first()[0])

    return sub_df

# Combinging all quarters into a single DataFrame
sub_data = (
    load_sub_data("2016q1")
    .union(load_sub_data("2016q2"))
    .union(load_sub_data("2016q3"))
    .union(load_sub_data("2016q4")))

sub_data.show(5)
# Out:
# +--------------------+-------+--------------------+----+---------+------+-------------------+----------+--------------------+--------------------+---------------+---------+------+-------------------+-------+--------------------+--------------------+----------+-------+---------+--------------------+--------+-----+----+----+------+--------+----+---+--------+--------------------+-------+------+-----------------+-----+-----+
# |                adsh|    cik|                name| sic|countryba|stprba|             cityba|     zipba|                bas1|                bas2|           baph|countryma|stprma|             cityma|  zipma|                mas1|                mas2|countryinc|stprinc|      ein|              former| changed|  afs|wksi| fye|  form|  period|  fy| fp|   filed|            accepted|prevrpt|detail|         instance|nciks|aciks|
# +--------------------+-------+--------------------+----+---------+------+-------------------+----------+--------------------+--------------------+---------------+---------+------+-------------------+-------+--------------------+--------------------+----------+-------+---------+--------------------+--------+-----+----+----+------+--------+----+---+--------+--------------------+-------+------+-----------------+-----+-----+
# |0001527541-16-000246|1527541|WHEELER REAL ESTA...|6798|       US|    VA|     VIRGINIA BEACH|     23452|    RIVERSEDGE NORTH|2529 VIRGINIA BEA...|   757-627-9088|       US|    VA|     VIRGINIA BEACH|  23452|    RIVERSEDGE NORTH|2529 VIRGINIA BEA...|        US|     MD|452681082|                NULL|    NULL|2-ACC|   0|1231|  10-K|20151231|2015| FY|20160310|2016-03-10 16:14:...|      0|     1|whlr-20151231.xml|    1| NULL|
# |0001169264-16-000032|1169264|SYNIVERSE HOLDING...|4899|       US|    FL|              TAMPA|     33647|8125 HIGHWOODS PA...|                NULL|     8136375000|       US|    FL|              TAMPA|  33647|8125 HIGHWOODS PA...|                NULL|        US|     DE|300041666|TSI TELECOMMUNICA...|20020315|4-NON|   0|1231|  10-K|20151231|2015| FY|20160329|2016-03-29 16:12:...|      0|     1| svr-20151231.xml|    1| NULL|
# |0000712534-16-000349| 712534|FIRST MERCHANTS CORP|6021|       US|    IN|             MUNCIE|47308-0792|    200 E JACKSON ST|          PO BOX 792|     7657471500|       US|    IN|             MUNCIE|  47305|200 EAST JACKSON ...|                NULL|        US|     IN|351544218|                NULL|    NULL|1-LAF|   0|1231|  10-K|20151231|2015| FY|20160229|2016-02-29 12:51:...|      0|     1|frme-20151231.xml|    1| NULL|
# |0001213900-16-010639|1112372|MEDICAL INTERNATI...|3841|       CA|    QC|VILLE SAINT-LAURENT|   HR4 2E7| 1872 BEAULAC STREET|                   .| (514) 339-9355|       CA|    QC|VILLE SAINT-LAURENT|HR4 2E7| 1872 BEAULAC STREET|                   .|        US|     CO|841509950| POSTERALLEY COM INC|20000824|5-SML|   0|0930|  10-Q|20141231|2015| Q1|20160205|2016-02-05 16:05:...|      0|     1|mdlh-20141231.xml|    1| NULL|
# |0001493152-16-006801|1590565|ASIA EQUITY EXCHA...|3663|       CN|  NULL|           SHENZHEN|    518000|DONFANG SCIENCE A...|UNIT 1705, NANSHA...|86 137 23493273|       CN|  NULL|           SHENZHEN| 518000|DONFANG SCIENCE A...|UNIT 1705, NANSHA...|        US|     NV|463366428|   I IN THE SKY INC.|20131112|5-SML|   0|0930|10-K/A|20150930|2015| FY|20160115|2016-01-15 12:06:...|      0|     1|aeex-20150930.xml|    1| NULL|
# +--------------------+-------+--------------------+----+---------+------+-------------------+----------+--------------------+--------------------+---------------+---------+------+-------------------+-------+--------------------+--------------------+----------+-------+---------+--------------------+--------+-----+----+----+------+--------+----+---+--------+--------------------+-------+------+-----------------+-----+-----+
# only showing top 5 rows

# %%
# Defining Schema
num_schema = StructType([
    StructField("adsh", StringType(), nullable=False),
    StructField("tag", StringType(), nullable=False),
    StructField("version", StringType(), nullable=False),
    StructField("ddate", DateType(), nullable=False),
    StructField("qtrs", IntegerType(), nullable=False),
    StructField("uom", StringType(), nullable=False),
    StructField("segments", StringType(), nullable=True),
    StructField("coreg", StringType(), nullable=True),
    StructField("value", FloatType(), nullable=True),
    StructField("footnote", StringType(), nullable=True)
])

# Function to load data for a specific quarter
def load_num_data(quarter):
    num_df = spark.read.option("delimiter", "\t") \
        .schema(num_schema) \
        .csv(f"/content/drive/Shareddrives/DATS6450-Project2/{quarter}/num.txt")

    num_df = num_df.replace("", None)
    num_df = num_df.filter(num_df.adsh != num_df.first()[0])

    return num_df

# Combining all quarters into a single DataFrame
num_data = (
    load_num_data("2016q1")
    .union(load_num_data("2016q2"))
    .union(load_num_data("2016q3"))
    .union(load_num_data("2016q4")))

num_data.show(5)
# Out:
# +--------------------+--------------------+------------+-----+----+---+--------------------+-----+----------+--------+
# |                adsh|                 tag|     version|ddate|qtrs|uom|            segments|coreg|     value|footnote|
# +--------------------+--------------------+------------+-----+----+---+--------------------+-----+----------+--------+
# |0000919574-16-012035|AccountsPayableCu...|us-gaap/2015| NULL|   0|USD|                NULL| NULL| 1807000.0|    NULL|
# |0001477932-16-009072|AccumulatedDeprec...|us-gaap/2014| NULL|   0|USD|                NULL| NULL|   70484.0|    NULL|
# |0001628280-16-010235|AccruedLiabilitie...|us-gaap/2015| NULL|   0|USD|                NULL| NULL|  4.8368E7|    NULL|
# |0000919574-16-012194|DueToRelatedParti...|us-gaap/2015| NULL|   0|USD|RelatedPartyTrans...| NULL|       0.0|    NULL|
# |0001140361-16-059398|       NetIncomeLoss|us-gaap/2015| NULL|   4|USD|PartnerCapitalCom...| NULL|-5438000.0|    NULL|
# +--------------------+--------------------+------------+-----+----+---+--------------------+-----+----------+--------+
# only showing top 5 rows

# %%
# Defining Schema
pre_schema = StructType([
    StructField("adsh", StringType(), nullable=False),
    StructField("report", IntegerType(), nullable=False),
    StructField("line", IntegerType(), nullable=False),
    StructField("stmt", StringType(), nullable=False),
    StructField("inpth", StringType(), nullable=False),
    StructField("rfile", StringType(), nullable=False),
    StructField("tag", StringType(), nullable=False),
    StructField("version", StringType(), nullable=False),
    StructField("plabel", StringType(), nullable=False),
    StructField("negating", StringType(), nullable=False)
])

# Loading data for all quarters
def load_pre_data(quarter):
    pre_df = spark.read.option("delimiter", "\t") \
        .schema(pre_schema) \
        .csv(f"/content/drive/Shareddrives/DATS6450-Project2/{quarter}/pre.txt")

    pre_df = pre_df.replace("", None)
    pre_df = pre_df.filter(pre_df.adsh != pre_df.first()[0])
    return pre_df

# Combining all quarters into a single DataFrame
pre_data = (
    load_pre_data("2016q1")
    .union(load_pre_data("2016q2"))
    .union(load_pre_data("2016q3"))
    .union(load_pre_data("2016q4")))

pre_data.show(5)
# Out:
# +--------------------+------+----+----+-----+-----+--------------------+------------+--------------------+--------+
# |                adsh|report|line|stmt|inpth|rfile|                 tag|     version|              plabel|negating|
# +--------------------+------+----+----+-----+-----+--------------------+------------+--------------------+--------+
# |0000002178-16-000064|     2|   3|  BS|    0|    H|CashAndCashEquiva...|us-gaap/2015|Cash and cash equ...|       0|
# |0000002178-16-000064|     2|   4|  BS|    0|    H|AccountsReceivabl...|us-gaap/2015|Accounts receivab...|       0|
# |0000002178-16-000064|     2|   5|  BS|    0|    H|EnergyRelatedInve...|us-gaap/2015|         Inventories|       0|
# |0000002178-16-000064|     2|   6|  BS|    0|    H|EnergyMarketingCo...|us-gaap/2015|Fair value contracts|       0|
# |0000002178-16-000064|     2|   7|  BS|    0|    H|IncomeTaxesReceiv...|us-gaap/2015|Income tax receiv...|       0|
# +--------------------+------+----+----+-----+-----+--------------------+------------+--------------------+--------+
# only showing top 5 rows

# %%
# Define Schema
tag_schema = StructType([
    StructField("tag", StringType(), nullable=False),
    StructField("version", StringType(), nullable=False),
    StructField("custom", StringType(), nullable=False),
    StructField("abstract", StringType(), nullable=False),
    StructField("datatype", StringType(), nullable=True),
    StructField("iord", StringType(), nullable=False),
    StructField("crdr", StringType(), nullable=True),
    StructField("tlabel", StringType(), nullable=True),
    StructField("doc", StringType(), nullable=True)
])

# Loading data for all quarters
def load_tag_data(quarter):
    tag_df = spark.read.option("delimiter", "\t") \
        .schema(tag_schema) \
        .csv(f"/content/drive/Shareddrives/DATS6450-Project2/{quarter}/tag.txt")

    tag_df = tag_df.replace("", None)
    tag_df = tag_df.filter(tag_df.tag != tag_df.first()[0])
    return tag_df

# Combining all quarters into a single DataFrame
tag_data = (
    load_tag_data("2016q1")
    .union(load_tag_data("2016q2"))
    .union(load_tag_data("2016q3"))
    .union(load_tag_data("2016q4")))

tag_data.show(5)
# Out:
# +--------------------+------------+------+--------+--------+----+----+--------------------+--------------------+
# |                 tag|     version|custom|abstract|datatype|iord|crdr|              tlabel|                 doc|
# +--------------------+------------+------+--------+--------+----+----+--------------------+--------------------+
# |AccountsPayableCu...|us-gaap/2014|     0|       0|monetary|   I|   C|Accounts Payable,...|Carrying value as...|
# |AccountsPayableRe...|us-gaap/2014|     0|       0|monetary|   I|   C|Accounts Payable,...|Amount for accoun...|
# |AccountsReceivabl...|us-gaap/2014|     0|       0|monetary|   I|   D|Accounts Receivab...|Amount, after all...|
# |AccruedLiabilitie...|us-gaap/2014|     0|       0|monetary|   I|   C|Accrued Liabiliti...|Carrying value as...|
# |AccumulatedDeprec...|us-gaap/2014|     0|       0|monetary|   I|   C|Accumulated Depre...|Amount of accumul...|
# +--------------------+------------+------+--------+--------+----+----+--------------------+--------------------+
# only showing top 5 rows

# %%
num_data = num_data.select(
    "adsh", "tag", "version", "qtrs", "uom", "value")

num_data.show(5)
sub_data = sub_data.select(
    "adsh", "cik", "name", "countryba", "stprba", "countryma", "stprma",
    "ein", "former", "changed", "afs", "fye", "form", "period", "fy",
    "fp", "filed", "nciks")

sub_data.show(5)
tag_data = tag_data.select("tag", "version", "abstract", "iord", "crdr", "tlabel")

tag_data.show()
pre_data = pre_data.select("adsh", "report", "line", "stmt", "inpth", "tag", "version", "plabel")

pre_data.show(5)
# Out:
# +--------------------+--------------------+------------+----+---+----------+
# |                adsh|                 tag|     version|qtrs|uom|     value|
# +--------------------+--------------------+------------+----+---+----------+
# |0000919574-16-012035|AccountsPayableCu...|us-gaap/2015|   0|USD| 1807000.0|
# |0001477932-16-009072|AccumulatedDeprec...|us-gaap/2014|   0|USD|   70484.0|
# |0001628280-16-010235|AccruedLiabilitie...|us-gaap/2015|   0|USD|  4.8368E7|
# |0000919574-16-012194|DueToRelatedParti...|us-gaap/2015|   0|USD|       0.0|
# |0001140361-16-059398|       NetIncomeLoss|us-gaap/2015|   4|USD|-5438000.0|
# +--------------------+--------------------+------------+----+---+----------+
# only showing top 5 rows
#
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+------+--------+----+---+--------+-----+
# |                adsh|    cik|                name|countryba|stprba|countryma|stprma|      ein|              former| changed|  afs| fye|  form|  period|  fy| fp|   filed|nciks|
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+------+--------+----+---+--------+-----+
# |0001527541-16-000246|1527541|WHEELER REAL ESTA...|       US|    VA|       US|    VA|452681082|                NULL|    NULL|2-ACC|1231|  10-K|20151231|2015| FY|20160310|    1|
# |0001169264-16-000032|1169264|SYNIVERSE HOLDING...|       US|    FL|       US|    FL|300041666|TSI TELECOMMUNICA...|20020315|4-NON|1231|  10-K|20151231|2015| FY|20160329|    1|
# |0000712534-16-000349| 712534|FIRST MERCHANTS CORP|       US|    IN|       US|    IN|351544218|                NULL|    NULL|1-LAF|1231|  10-K|20151231|2015| FY|20160229|    1|
# |0001213900-16-010639|1112372|MEDICAL INTERNATI...|       CA|    QC|       CA|    QC|841509950| POSTERALLEY COM INC|20000824|5-SML|0930|  10-Q|20141231|2015| Q1|20160205|    1|
# |0001493152-16-006801|1590565|ASIA EQUITY EXCHA...|       CN|  NULL|       CN|  NULL|463366428|   I IN THE SKY INC.|20131112|5-SML|0930|10-K/A|20150930|2015| FY|20160115|    1|
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+------+--------+----+---+--------+-----+
# only showing top 5 rows
#
# +--------------------+------------+--------+----+----+--------------------+
# |                 tag|     version|abstract|iord|crdr|              tlabel|
# +--------------------+------------+--------+----+----+--------------------+
# |AccountsPayableCu...|us-gaap/2014|       0|   I|   C|Accounts Payable,...|
# |AccountsPayableRe...|us-gaap/2014|       0|   I|   C|Accounts Payable,...|
# |AccountsReceivabl...|us-gaap/2014|       0|   I|   D|Accounts Receivab...|
# |AccruedLiabilitie...|us-gaap/2014|       0|   I|   C|Accrued Liabiliti...|
# |AccumulatedDeprec...|us-gaap/2014|       0|   I|   C|Accumulated Depre...|
# |AdditionalPaidInC...|us-gaap/2014|       0|   I|   C|Additional Paid i...|
# |AllowanceForDoubt...|us-gaap/2014|       0|   I|   C|Accounts Receivab...|
# |AssetRetirementOb...|us-gaap/2014|       0|   I|   C|Asset Retirement ...|
# |              Assets|us-gaap/2014|       0|   I|   D|              Assets|
# |       AssetsCurrent|us-gaap/2014|       0|   I|   D|     Assets, Current|
# |AssetsOfDisposalG...|us-gaap/2014|       0|   I|   D|Disposal Group, I...|
# |CashAndCashEquiva...|us-gaap/2014|       0|   I|   D|Cash and Cash Equ...|
# |CashAndCashEquiva...|us-gaap/2014|       0|   D|   D|Cash and Cash Equ...|
# |CommitmentsAndCon...|us-gaap/2014|       0|   I|   C|Commitments and C...|
# |CommonStockDivide...|us-gaap/2014|       0|   D|NULL|Common Stock, Div...|
# |CommonStockParOrS...|us-gaap/2014|       0|   I|NULL|Common Stock, Par...|
# |CommonStockShares...|us-gaap/2014|       0|   I|NULL|Common Stock, Sha...|
# |CommonStockShares...|us-gaap/2014|       0|   I|NULL|Common Stock, Sha...|
# |CommonStockShares...|us-gaap/2014|       0|   I|NULL|Common Stock, Sha...|
# |    CommonStockValue|us-gaap/2014|       0|   I|   C|Common Stock, Val...|
# +--------------------+------------+--------+----+----+--------------------+
# only showing top 20 rows
#
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# |                adsh|report|line|stmt|inpth|                 tag|     version|              plabel|
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# |0000002178-16-000064|     2|   3|  BS|    0|CashAndCashEquiva...|us-gaap/2015|Cash and cash equ...|
# |0000002178-16-000064|     2|   4|  BS|    0|AccountsReceivabl...|us-gaap/2015|Accounts receivab...|
# |0000002178-16-000064|     2|   5|  BS|    0|EnergyRelatedInve...|us-gaap/2015|         Inventories|
# |0000002178-16-000064|     2|   6|  BS|    0|EnergyMarketingCo...|us-gaap/2015|Fair value contracts|
# |0000002178-16-000064|     2|   7|  BS|    0|IncomeTaxesReceiv...|us-gaap/2015|Income tax receiv...|
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# only showing top 5 rows

# %%
sub_data = sub_data.dropna()
num_data = num_data.dropna()
tag_data = tag_data.dropna()
pre_data = pre_data.dropna()

num_data.show(5)
tag_data.show(5)
pre_data.show(5)
sub_data.show(5)
# Out:
# +--------------------+--------------------+------------+----+---+----------+
# |                adsh|                 tag|     version|qtrs|uom|     value|
# +--------------------+--------------------+------------+----+---+----------+
# |0000919574-16-012035|AccountsPayableCu...|us-gaap/2015|   0|USD| 1807000.0|
# |0001477932-16-009072|AccumulatedDeprec...|us-gaap/2014|   0|USD|   70484.0|
# |0001628280-16-010235|AccruedLiabilitie...|us-gaap/2015|   0|USD|  4.8368E7|
# |0000919574-16-012194|DueToRelatedParti...|us-gaap/2015|   0|USD|       0.0|
# |0001140361-16-059398|       NetIncomeLoss|us-gaap/2015|   4|USD|-5438000.0|
# +--------------------+--------------------+------------+----+---+----------+
# only showing top 5 rows
#
# +--------------------+------------+--------+----+----+--------------------+
# |                 tag|     version|abstract|iord|crdr|              tlabel|
# +--------------------+------------+--------+----+----+--------------------+
# |AccountsPayableCu...|us-gaap/2014|       0|   I|   C|Accounts Payable,...|
# |AccountsPayableRe...|us-gaap/2014|       0|   I|   C|Accounts Payable,...|
# |AccountsReceivabl...|us-gaap/2014|       0|   I|   D|Accounts Receivab...|
# |AccruedLiabilitie...|us-gaap/2014|       0|   I|   C|Accrued Liabiliti...|
# |AccumulatedDeprec...|us-gaap/2014|       0|   I|   C|Accumulated Depre...|
# +--------------------+------------+--------+----+----+--------------------+
# only showing top 5 rows
#
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# |                adsh|report|line|stmt|inpth|                 tag|     version|              plabel|
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# |0000002178-16-000064|     2|   3|  BS|    0|CashAndCashEquiva...|us-gaap/2015|Cash and cash equ...|
# |0000002178-16-000064|     2|   4|  BS|    0|AccountsReceivabl...|us-gaap/2015|Accounts receivab...|
# |0000002178-16-000064|     2|   5|  BS|    0|EnergyRelatedInve...|us-gaap/2015|         Inventories|
# |0000002178-16-000064|     2|   6|  BS|    0|EnergyMarketingCo...|us-gaap/2015|Fair value contracts|
# |0000002178-16-000064|     2|   7|  BS|    0|IncomeTaxesReceiv...|us-gaap/2015|Income tax receiv...|
# +--------------------+------+----+----+-----+--------------------+------------+--------------------+
# only showing top 5 rows
#
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+----+--------+----+---+--------+-----+
# |                adsh|    cik|                name|countryba|stprba|countryma|stprma|      ein|              former| changed|  afs| fye|form|  period|  fy| fp|   filed|nciks|
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+----+--------+----+---+--------+-----+
# |0001169264-16-000032|1169264|SYNIVERSE HOLDING...|       US|    FL|       US|    FL|300041666|TSI TELECOMMUNICA...|20020315|4-NON|1231|10-K|20151231|2015| FY|20160329|    1|
# |0001213900-16-010639|1112372|MEDICAL INTERNATI...|       CA|    QC|       CA|    QC|841509950| POSTERALLEY COM INC|20000824|5-SML|0930|10-Q|20141231|2015| Q1|20160205|    1|
# |0001433714-16-000059|1433714|CASTLIGHT HEALTH,...|       US|    CA|       US|    CA|261989091|VENTANA HEALTH SE...|20090831|2-ACC|1231|10-K|20151231|2015| FY|20160310|    1|
# |0000021510-16-000043|  21510|        COHERENT INC|       US|    CA|       US|    CA|941622541|  COHERENT RADIATION|19770604|1-LAF|0930|10-Q|20151231|2016| Q1|20160210|    1|
# |0000350698-16-000276| 350698|    AUTONATION, INC.|       US|    FL|       US|    FL|731105145|AUTONATION, INC. /FL|20090827|1-LAF|1231|10-K|20151231|2015| FY|20160211|    1|
# +--------------------+-------+--------------------+---------+------+---------+------+---------+--------------------+--------+-----+----+----+--------+----+---+--------+-----+
# only showing top 5 rows

# %%
total_rows = sub_data.count()
total_columns = len(sub_data.columns)

print(f"\nTotal shape of sub_data DataFrame: ({total_rows}, {total_columns})")

total_rows = num_data.count()
total_columns = len(num_data.columns)

print(f"\nTotal shape of num_data DataFrame: ({total_rows}, {total_columns})")

total_rows = tag_data.count()
total_columns = len(tag_data.columns)

print(f"\nTotal shape of tag_data DataFrame: ({total_rows}, {total_columns})")

total_rows = pre_data.count()
total_columns = len(pre_data.columns)

print(f"\nTotal shape of num_data DataFrame: ({total_rows}, {total_columns})")
# Out:
# Total shape of sub_data DataFrame: (12681, 18)
#
# Total shape of num_data DataFrame: (10290627, 6)
#
# Total shape of tag_data DataFrame: (216448, 6)
#
# Total shape of num_data DataFrame: (2734585, 8)

# %%
# Filter PRE data for specific stmt values
stmt_values = ["BS", "IS", "CF", "EQ", "CI", "SI"]
filtered_pre_data = pre_data.filter(pre_data.stmt.isin(stmt_values))

# Join SUB and PRE on adsh
sub_pre_joined = sub_data.join(filtered_pre_data, on="adsh", how="inner")

# Join NUM and SUB and PRE on adsh, version, and tag
num_pre_joined = sub_pre_joined.join(num_data, on=["adsh", "version", "tag"], how="inner")

num_pre_joined = num_pre_joined.dropDuplicates()

num_pre_joined.show(5)
print(num_pre_joined.count())

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import FloatType

num_pre_joined = num_pre_joined.withColumn("value", F.col("value").cast(FloatType()))
crdr_mapping = {row.tag: row.crdr for row in tag_data.select("tag", "crdr").collect()}

# Broadcast the dictionary to optimize access
crdr_broadcast = spark.sparkContext.broadcast(crdr_mapping)

# Define a UDF to map the crdr value
def get_crdr(tag):
    return crdr_broadcast.value.get(tag, None)

# Register the UDF
get_crdr_udf = F.udf(get_crdr)
num_pre_joined = num_pre_joined.withColumn("crdr", get_crdr_udf(F.col("tag")))

category_rules = {
    "revenue": "D",
    "income": "D",
    "assets": "D",
    "debt": "C",
    "liability": "C"
}

agg_exprs = [
    F.sum(F.when(F.col("crdr") == crdr_value, F.col("value")).otherwise(0)).alias(category)
    for category, crdr_value in category_rules.items()
]

tag_sums = num_pre_joined.groupBy("tag").agg(*agg_exprs)

zero_sum_tags = tag_sums.filter(
    F.greatest(*[F.col(category) for category in category_rules.keys()]) == 0
).select("tag")

zero_sum_tag_list = [row.tag for row in zero_sum_tags.collect()]

num_pre_joined = num_pre_joined.filter(~F.col("tag").isin(zero_sum_tag_list))

# %%
from pyspark.sql import functions as F

# Add the new tag category column
num_pre_joined = num_pre_joined.withColumn(
    "tag_category",
    F.when((F.lower(F.col("tag")).rlike(".*income.*")) & (F.col("crdr") == 'C'), "income")  # Includes any tag with 'income'
      .when((F.lower(F.col("tag")).rlike(".*revenue.*")) & (F.col("crdr") == 'C'), "revenue")  # Includes any tag with 'revenue'
      .when((F.lower(F.col("tag")).rlike(".*asset.*")) & (F.col("crdr") == 'C'), "asset")      # Includes any tag with 'asset'
      .when((F.lower(F.col("tag")).rlike(".*debt.*")) & (F.col("crdr") == 'D'), "debt")        # Includes any tag with 'debt'
      .when((F.lower(F.col("tag")).rlike(".*liability.*")) & (F.col("crdr") == 'D'), "liability")  # Includes any tag with 'liability'
      .otherwise("other")  # Default case
)
num_pre_joined.show(5)

# %%
from neo4j import GraphDatabase
from pyspark.sql import functions as F

# Neo4j Connection
NEO4J_URI = "neo4j+s://22e0ea28.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "7L6AUSP97VOZFcl5dEeSIFCwacdVwgttCA5ZPsm3UgQ"

def load_company_nodes(df,batch_id):
    """
    Loads unique `cik` values as nodes and merges selected financial properties.
    - `name`, `tag`, `fp`, `stmt`, and `fye` are collected as sets.
    - `value` is summed for each `cik`.
    """

    # Aggregate specified properties and sum `value` for each `cik`
    df_grouped = df.groupBy("cik").agg(
        F.collect_set("name").alias("names"),  # Collect unique names
        F.collect_set("tag").alias("tags"),    # Collect unique tags
        F.collect_set("fp").alias("fps"),      # Collect unique fp values
        F.collect_set("stmt").alias("stmts"),   # Collect unique stmt values
        F.collect_set("fye").alias("fyes"),     # Collect unique fye values
        F.sum("value").alias("total_value")     # Sum of values
    )

    def process_partition(partition):
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session() as session:
                for row in partition:
                    query = """
                    MERGE (c:Company {cik: $cik})
                    SET c.names = $names,
                        c.tags = $tags,
                        c.fps = $fps,
                        c.stmts = $stmts,
                        c.fyes = $fyes,
                        c.total_value = $total_value
                    """
                    session.run(query,
                                cik=row["cik"],
                                names=list(row["names"]),   # Convert collected set to list
                                tags=list(row["tags"]),
                                fps=list(row["fps"]),
                                stmts=list(row["stmts"]),
                                fyes=list(row["fyes"]),
                                total_value=row["total_value"])
        finally:
            driver.close()

    df_grouped.foreachPartition(process_partition)

# Load data from num_pre_joined
load_company_nodes(num_pre_joined, batch_id='main_graph')

# %%
import pandas as pd
def fetch_grouped_data():
    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    query = """
    MATCH (c:Company)
    WITH c.cik AS cik, c.names AS names, c.tags AS tags, c.fps AS fps, c.total_value AS total_value
    UNWIND names AS name
    UNWIND tags AS tag
    UNWIND fps AS fp
    // Categorize tags based on keywords
    WITH
        cik,
        name,
        CASE
            WHEN toLower(tag) CONTAINS 'revenue' THEN 'Revenue'
            WHEN toLower(tag) CONTAINS 'income' THEN 'Income'
            WHEN toLower(tag) CONTAINS 'debt' THEN 'Debt'
            WHEN toLower(tag) CONTAINS 'assets' THEN 'Assets'
            WHEN toLower(tag) CONTAINS 'liabilities' THEN 'Liabilities'
            ELSE 'Other'  // Handle tags that don't match any condition
        END AS tag_category,
        fp,
        total_value
    // Group by cik, name, tag_category, and fp, and sum total_value
    RETURN
        cik,
        name,
        tag_category,
        fp,
        SUM(total_value) AS total_value
    ORDER BY cik, name, tag_category, fp
    """

    with driver.session() as session:
        result = session.run(query)
        output_data = [record.data() for record in result]

    driver.close()
    return output_data

# Fetch grouped data
grouped_data = fetch_grouped_data()

# Create a DataFrame from the fetched data
df_grouped_data = pd.DataFrame(grouped_data)

print(df_grouped_data)

total_rows = len(df_grouped_data)
total_columns = len(df_grouped_data.columns)
print(f"\nTotal shape of grouped data: ({total_rows}, {total_columns})")
# Out:
#             cik                    name tag_category  fp   total_value
# 0       1000045  NICHOLAS FINANCIAL INC       Assets  FY  1.868280e+12
# 1       1000045  NICHOLAS FINANCIAL INC       Assets  Q1  1.868280e+12
# 2       1000045  NICHOLAS FINANCIAL INC       Assets  Q2  1.868280e+12
# 3       1000045  NICHOLAS FINANCIAL INC       Assets  Q3  1.868280e+12
# 4       1000045  NICHOLAS FINANCIAL INC         Debt  FY  2.668971e+11
# ...         ...                     ...          ...  ..           ...
# 150002     9984        BARNES GROUP INC        Other  Q3  1.008689e+13
# 150003     9984        BARNES GROUP INC      Revenue  FY  3.879575e+11
# 150004     9984        BARNES GROUP INC      Revenue  Q1  3.879575e+11
# 150005     9984        BARNES GROUP INC      Revenue  Q2  3.879575e+11
# 150006     9984        BARNES GROUP INC      Revenue  Q3  3.879575e+11
#
# [150007 rows x 5 columns]
#
# Total shape of grouped data: (150007, 5)

# %%
categories = ["Revenue", "Debt", "Assets", "Liabilities", "Income"]  # Specified categories

filtered_rows = []

# Loop through each category and get 20 rows for each
for category in categories:
    category_rows = df_grouped_data[df_grouped_data['tag_category'] == category].head(20)
    filtered_rows.append(category_rows)

filtered_df = pd.concat(filtered_rows)
print(filtered_df)
# Out:
#          cik                          name tag_category  fp   total_value
# 20   1000045        NICHOLAS FINANCIAL INC      Revenue  FY  5.337942e+11
# 21   1000045        NICHOLAS FINANCIAL INC      Revenue  Q1  5.337942e+11
# 22   1000045        NICHOLAS FINANCIAL INC      Revenue  Q2  5.337942e+11
# 23   1000045        NICHOLAS FINANCIAL INC      Revenue  Q3  5.337942e+11
# 29   1000177   NORDIC AMERICAN TANKERS LTD      Revenue  FY  1.677138e+11
# ..       ...                           ...          ...  ..           ...
# 96   1000230            OPTICAL CABLE CORP       Income  FY  1.578437e+11
# 97   1000230            OPTICAL CABLE CORP       Income  Q1  1.578437e+11
# 98   1000230            OPTICAL CABLE CORP       Income  Q2  1.578437e+11
# 116  1000232  KENTUCKY BANCSHARES INC /KY/       Income  FY  3.802694e+12
# 117  1000232  KENTUCKY BANCSHARES INC /KY/       Income  Q1  3.802694e+12
#
# [100 rows x 5 columns]

# %%
! pip install sec-api
# Out:
# Requirement already satisfied: sec-api in /usr/local/lib/python3.11/dist-packages (1.0.29)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from sec-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->sec-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->sec-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->sec-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->sec-api) (2025.1.31)

# %%
import pandas as pd
from pyspark.sql.functions import col, lit, when
import requests
import time
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from neo4j import GraphDatabase
import matplotlib.pyplot as plt

sub_data_10K = sub_data.select("cik", "name")
sub_data_10K = sub_data_10K.toPandas()
sub_data_10K.head()
# Out:
#        cik                                        name
# 0  1527541  WHEELER REAL ESTATE INVESTMENT TRUST, INC.
# 1  1169264                      SYNIVERSE HOLDINGS INC
# 2   712534                        FIRST MERCHANTS CORP
# 3  1112372        MEDICAL INTERNATIONAL TECHNOLOGY INC
# 4  1590565            ASIA EQUITY EXCHANGE GROUP, INC.

# %%
distinct_cik = sub_data_10K["cik"].unique()
distinct_cik
# Out:
# array(['1527541', '1169264', '712534', ..., '1679817', '1393935',
#        '1512228'], dtype=object)

# %%
distinct_cik_1 = pd.Series(distinct_cik)
distinct_cik_1.head()
# Out:
# 0    1527541
# 1    1169264
# 2     712534
# 3    1112372
# 4    1590565
# dtype: object

# %% [markdown]
# We imported requests to fetch data from SEC API and beautifulsoup to scrape and parse the relevenat data points from HTML documents. We construced the API requests using company CIK identifiers. We had to extract executive names from the signature section in the filings that list executives and board members.

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
from datetime import datetime
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

# ---------------- CONFIGURATION ----------------
USER_AGENT = "aishitha.pacipala@gwmail.gwu.edu"
TIMEOUT = 10
HEADERS = {"User-Agent": USER_AGENT}

# ---------------- FETCHING FUNCTIONS ----------------
def fetch_submission(cik):
    cik = str(cik).zfill(10)
    url = f"https://data.sec.gov/submissions/CIK{cik}.json"
    response = requests.get(url, headers=HEADERS, timeout=TIMEOUT)
    response.raise_for_status()
    return response.json()

def get_filing_url(submissions, form_type, year):
    filings = submissions["filings"]["recent"]
    for form, date_str, acc, primary in zip(
        filings["form"], filings["filingDate"], filings["accessionNumber"], filings["primaryDocument"]
    ):
        if form.upper() == form_type.upper():
            filing_date = datetime.strptime(date_str, "%Y-%m-%d")
            if filing_date.year == year:
                acc_no = acc.replace("-", "")
                if primary and primary.strip():
                    return f"https://www.sec.gov/Archives/edgar/data/{int(submissions['cik'])}/{acc_no}/{primary}"
                else:
                    return f"https://www.sec.gov/Archives/edgar/data/{int(submissions['cik'])}/{acc_no}.txt"
    return None

def fetch_filing_content(filing_url):
    response = requests.get(filing_url, headers=HEADERS, timeout=TIMEOUT)
    response.raise_for_status()
    return response.text

# ---------------- EXTRACTION FUNCTIONS ----------------

def extract_signature_section(html):
    """
    Attempt to locate the signature section in an SEC filing, even if:
      - 'SIGNATURES' appears multiple times
      - It's sometimes in <b> or with a bold style
      - It's near the end, or in the middle
    We'll do a fallback approach: first look for <b> 'SIGNATURES', else fallback
    to the last text occurrence of 'SIGNATURES' or 'SIGNATURE'.
    Then end at the next known boundary like 'EXHIBIT', '</DOCUMENT>', etc.
    """
    # -- Step 1: Collapse all whitespace for easier regex searching --
    collapsed = re.sub(r"\s+", " ", html)

    # -- Step 2: Attempt to locate bolded SIGNATURES if it exists --
    #    e.g., <b>SIGNATURES</b> or <tag style="font-weight:bold">SIGNATURES</tag>
    bold_pattern = re.compile(
        r"""(?i)            # ignore case
        (?:<b[^>]*>\s*SIGNATURES\s*</b>) |
        (?:<[a-zA-Z]+\s+[^>]*style\s*=\s*["'][^"']*font-weight\s*:\s*bold;?[^"']*["'][^>]*>\s*SIGNATURES\s*</[a-zA-Z]+>)
        """,
        re.VERBOSE
    )
    bold_matches = list(bold_pattern.finditer(collapsed))

    if bold_matches:
        # If we find bold SIGNATURES, pick the last occurrence
        last_bold = bold_matches[-1]
        start_idx = last_bold.start()
    else:
        # -- Step 3: Fallback to last occurrence of SIGNATURE(S) ignoring case --
        #    We also allow for singular SIGNATURE
        generic_pattern = re.compile(r"SIGNATURES?", re.IGNORECASE)
        matches = list(generic_pattern.finditer(collapsed))
        if not matches:
            return None  # No signature reference found at all
        # pick the last occurrence
        last_match = matches[-1]
        start_idx = last_match.start()

    # -- Step 4: Define an end boundary for the signature section
    #    e.g., next "EXHIBIT", closing tags, or end of file
    end_pattern = re.compile(r"(EXHIBIT\s|</HTML>|</DOCUMENT>|</SEC-HEADER>|$)", re.IGNORECASE)
    end_match = end_pattern.search(collapsed, start_idx)
    end_idx = end_match.start() if end_match else len(collapsed)

    # -- Step 5: Extract the substring
    signature_section = collapsed[start_idx:end_idx].strip()

    return signature_section


# ---------------- HELPER FUNCTIONS ----------------
def clean_line(line):
    return line.strip()

def is_date(text):
    return bool(re.search(r"(January|February|March|April|May|June|July|August|September|October|November|December)\s+\d{1,2},\s+\d{4}", text, re.IGNORECASE))

def guess_position(line):
    keywords = ["director", "officer", "president", "chief", "executive", "senior", "vice president", "title"]
    return any(kw in line.lower() for kw in keywords)

def parse_signature_entry(entry, cik):
    """
    Parse a signature block.
    If the entry contains newline characters, use the line-by-line heuristic:
      - First non-empty line is assumed to be the Name.
      - If >=3 lines and the second line looks like a date, use the third line as Position;
        otherwise, use the second line.
    If there are no newline characters, split on two or more spaces.
    """
    entry = entry.strip()
    name = ""
    position = ""
    # Check if entry contains newline characters
    if "\n" in entry:
        lines = [clean_line(l) for l in entry.splitlines() if l.strip()]
        if not lines:
            return None
        name = lines[0]

    return {"CIK": cik, "Name": name}



def is_valid_entry(entry):
    """
    Returns False if the entry's name is missing, too short, or matches a known heading.
    """
    name = entry.get("Name", "").strip().lower()
    if not name or len(name) < 3 or len(name) > 40:
        return False
    if re.search(r"\b(signatures?)\b", name, re.IGNORECASE):
        return False
    if re.search(r"(LLC|LLP)\s*[\.,]?$", name, re.IGNORECASE):
        return False
    return True

def parse_signatures_from_text(text, cik):
    """
    Split the entire text using the /s/ marker (with following whitespace) and parse each block.
    """
    entries = re.split(r"(?i)/s/\s+", text)
    results = []
    for entry in entries:
        entry = entry.strip()
        if not entry:
            continue
        parsed = parse_signature_entry(entry, cik)
        if parsed and is_valid_entry(parsed):
            results.append(parsed)
    return results


def parse_directors_for_cik(cik, form_type, year=2017):
    submissions = fetch_submission(cik)
    filing_url = get_filing_url(submissions, form_type, year)
    print(filing_url)
    if not filing_url:
        print(f"CIK {cik}: No filing URL found.")
        return pd.DataFrame(columns=["CIK", "Name"])
    html_content = fetch_filing_content(filing_url)
    sig_section = extract_signature_section(html_content)
    if not sig_section:
        print(f"CIK {cik}: No SIGNATURES section found.")
        return pd.DataFrame(columns=["CIK", "Name"])

    # plain text extraction.
    soup = BeautifulSoup(sig_section, "html.parser")
    text = soup.get_text(separator="\n").strip()
    text_results = parse_signatures_from_text(text, cik)
    return pd.DataFrame(text_results, columns=["CIK", "Name"])

# ---------------- MAIN EXECUTION ----------------
if __name__ == "__main__":
    pd.set_option('display.max_colwidth', None)
    final_df = pd.DataFrame(columns=["CIK", "Name"])

    for i, cik in enumerate(distinct_cik_1):
        try:
            df = parse_directors_for_cik(cik, "10-K", year=2016)
            print(f'CIK:{cik} Progess: {i}/{len(distinct_cik_1)}')
            final_df = pd.concat([final_df, df], ignore_index=True)
        except requests.exceptions.ReadTimeout:
            print(f"Read timeout for CIK {cik}. Retrying in 5 seconds...")
            # Try again after a delay:
            try:
                df = parse_directors_for_cik(cik, "10-K", year=2016)
                print(f'CIK:{cik} Progess: {i}/{len(distinct_cik_1)}')
                print(df)
                final_df = pd.concat([final_df, df], ignore_index=True)
            except requests.exceptions.ReadTimeout:
                print(f"Second read timeout for CIK {cik}. Skipping...")

    print("Finish!")
    print(final_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# None
# CIK 813828: No filing URL found.
# CIK:813828 Progess: 5018/7213
# https://www.sec.gov/Archives/edgar/data/1516973/000151697316000057/mtge20151231form10k.htm
# CIK:1516973 Progess: 5019/7213
# https://www.sec.gov/Archives/edgar/data/1637757/000163775716000016/yieldllc1231201510-k.htm
# CIK:1637757 Progess: 5020/7213
# None
# CIK 1371285: No filing URL found.
# CIK:1371285 Progess: 5021/7213
# https://www.sec.gov/Archives/edgar/data/1526689/000164033416001762/vend_10k.htm
# CIK:1526689 Progess: 5022/7213
# https://www.sec.gov/Archives/edgar/data/1221554/000114420416112910/v444107_10k.htm
# CIK:1221554 Progess: 5023/7213
# https://www.sec.gov/Archives/edgar/data/907254/000090725416000153/bfs-12312015x10k.htm
# CIK:907254 Progess: 5024/7213
# https://www.sec.gov/Archives/edgar/data/63908/000006390816000103/mcd-12312015x10k.htm
# CIK:63908 Progess: 5025/7213
# https://www.sec.gov/Archives/edgar/data/928022/000092802216000132/cpe-20151231x10k.htm
# CIK:928022 Progess: 5026/7213
# https://www.sec.gov/Archives/edgar/data/1621434/000156459016014218/bsm-10k_20151231.htm
# CIK:1621434 Progess: 5027/7213
# https://www.sec.gov/Archives/edgar/data/1078207/000107820716000064/nautilus10-k2015.htm
# CIK:1078207 Progess: 5028/7213
# https://www.sec.gov/Archives/edgar/data/1615892/000161589216000018/arcapacq-12x31x2015x10k.htm
# CIK:1615892 Progess: 5029/7213
# https://www.sec.gov/Archives/edgar/data/1230276/000123027616000057/p-12312015x10k.htm
# CIK:1230276 Progess: 5030/7213
# https://www.sec.gov/Archives/edgar/data/1360901/000136090116000017/evr1231201510k.htm
# CIK:1360901 Progess: 5031/7213
# https://www.sec.gov/Archives/edgar/data/1419581/000162828016011881/fdml-2015123110xk.htm
# CIK:1419581 Progess: 5032/7213
# https://www.sec.gov/Archives/edgar/data/74046/000007404616000094/odc10k7312016.htm
# CIK:74046 Progess: 5033/7213
# https://www.sec.gov/Archives/edgar/data/1079577/000119312516482052/d114296d10k.htm
# CIK:1079577 Progess: 5034/7213
# https://www.sec.gov/Archives/edgar/data/1386164/000119312516519711/d101880d10k.htm
# CIK:1386164 Progess: 5035/7213
# https://www.sec.gov/Archives/edgar/data/1339469/000119312516508691/d116551d10k.htm
# CIK:1339469 Progess: 5036/7213
# https://www.sec.gov/Archives/edgar/data/1104188/000119312516479332/d86734d10k.htm
# CIK:1104188 Progess: 5037/7213
# None
# CIK 16918: No filing URL found.
# CIK:16918 Progess: 5038/7213
# https://www.sec.gov/Archives/edgar/data/1287865/000119312516485612/d88578d10k.htm
# CIK:1287865 Progess: 5039/7213
# None
# CIK 1442999: No filing URL found.
# CIK:1442999 Progess: 5040/7213
# https://www.sec.gov/Archives/edgar/data/1158780/000117891316006442/zk1618969.htm
# CIK:1158780 Progess: 5041/7213
# https://www.sec.gov/Archives/edgar/data/1056087/000155837016003878/mni-20151227x10k.htm
# CIK:1056087 Progess: 5042/7213
# None
# CIK 1163302: No filing URL found.
# CIK:1163302 Progess: 5043/7213
# https://www.sec.gov/Archives/edgar/data/27093/000117152016001006/eps6897.htm
# CIK:27093 Progess: 5044/7213
# https://www.sec.gov/Archives/edgar/data/1105184/000110518416000042/nsph-20151231x10k.htm
# CIK:1105184 Progess: 5045/7213
# https://www.sec.gov/Archives/edgar/data/1487952/000148795216000067/vpg-20151231x10k.htm
# CIK:1487952 Progess: 5046/7213
# https://www.sec.gov/Archives/edgar/data/1055160/000105516016000119/mfa-12312015x10k.htm
# CIK:1055160 Progess: 5047/7213
# https://www.sec.gov/Archives/edgar/data/1450335/000137647416000633/cigf7_10k.htm
# CIK:1450335 Progess: 5048/7213
# None
# CIK 97745: No filing URL found.
# CIK:97745 Progess: 5049/7213
# None
# CIK 1372167: No filing URL found.
# CIK:1372167 Progess: 5050/7213
# https://www.sec.gov/Archives/edgar/data/1334036/000104746916010591/a2227543z10-k.htm
# CIK:1334036 Progess: 5051/7213
# https://www.sec.gov/Archives/edgar/data/1102112/000162828016011915/a12311510-k.htm
# CIK:1102112 Progess: 5052/7213
# https://www.sec.gov/Archives/edgar/data/1047127/000104712716000049/amkr12311510k.htm
# CIK:1047127 Progess: 5053/7213
# https://www.sec.gov/Archives/edgar/data/1019272/000114420416091278/v434553_10k.htm
# CIK:1019272 Progess: 5054/7213
# https://www.sec.gov/Archives/edgar/data/1378590/000143774916043488/blin20160901_10k.htm
# CIK:1378590 Progess: 5055/7213
# None
# CIK 1506295: No filing URL found.
# CIK:1506295 Progess: 5056/7213
# https://www.sec.gov/Archives/edgar/data/1402328/000135448816006700/sbfm_10k.htm
# CIK:1402328 Progess: 5057/7213
# https://www.sec.gov/Archives/edgar/data/1564618/000156461816000153/a201510-k.htm
# CIK:1564618 Progess: 5058/7213
# https://www.sec.gov/Archives/edgar/data/935036/000119312516481404/d102846d10k.htm
# CIK:935036 Progess: 5059/7213
# https://www.sec.gov/Archives/edgar/data/1574532/000119312516471714/d103561d10k.htm
# CIK:1574532 Progess: 5060/7213
# None
# CIK 1537118: No filing URL found.
# CIK:1537118 Progess: 5061/7213
# https://www.sec.gov/Archives/edgar/data/1276520/000119312516482185/d52855d10k.htm
# CIK:1276520 Progess: 5062/7213
# https://www.sec.gov/Archives/edgar/data/1134765/000141588916005263/truu10k_dec312015.htm
# CIK:1134765 Progess: 5063/7213
# https://www.sec.gov/Archives/edgar/data/1051627/000155837016004062/axti-20151231x10k.htm
# CIK:1051627 Progess: 5064/7213
# None
# CIK 733269: No filing URL found.
# CIK:733269 Progess: 5065/7213
# None
# CIK 759944: No filing URL found.
# CIK:759944 Progess: 5066/7213
# https://www.sec.gov/Archives/edgar/data/1166388/000116638816000180/vrnt-20160131xform10xk.htm
# CIK:1166388 Progess: 5067/7213
# https://www.sec.gov/Archives/edgar/data/859737/000085973716000071/holx_q4-2016.htm
# CIK:859737 Progess: 5068/7213
# None
# CIK 1099800: No filing URL found.
# CIK:1099800 Progess: 5069/7213
# https://www.sec.gov/Archives/edgar/data/1584207/000158420716000065/omh-20151231x10k.htm
# CIK:1584207 Progess: 5070/7213
# https://www.sec.gov/Archives/edgar/data/51011/000114036116080791/form10k.htm
# CIK:51011 Progess: 5071/7213
# https://www.sec.gov/Archives/edgar/data/1474439/000147443916000184/tnav630201610k.htm
# CIK:1474439 Progess: 5072/7213
# https://www.sec.gov/Archives/edgar/data/29002/000156459016014609/diod-10k_20151231.htm
# CIK:29002 Progess: 5073/7213
# https://www.sec.gov/Archives/edgar/data/1517022/000156459016014700/akba-10k_20151231.htm
# CIK:1517022 Progess: 5074/7213
# None
# CIK 1469367: No filing URL found.
# CIK:1469367 Progess: 5075/7213
# https://www.sec.gov/Archives/edgar/data/1361937/000114420416084719/v429416_10k.htm
# CIK:1361937 Progess: 5076/7213
# https://www.sec.gov/Archives/edgar/data/1030469/000103046916000067/ofg10k12312015.htm
# CIK:1030469 Progess: 5077/7213
# https://www.sec.gov/Archives/edgar/data/60977/000162828016011650/ldl-2015123110k.htm
# CIK:60977 Progess: 5078/7213
# https://www.sec.gov/Archives/edgar/data/1326190/000114420416087617/v433058_10k.htm
# CIK:1326190 Progess: 5079/7213
# https://www.sec.gov/Archives/edgar/data/1083446/000114420416110594/v442479_10k.htm
# CIK:1083446 Progess: 5080/7213
# https://www.sec.gov/Archives/edgar/data/1389772/000156459016015282/fpbk-10k_20151231.htm
# CIK:1389772 Progess: 5081/7213
# None
# CIK 1540047: No filing URL found.
# CIK:1540047 Progess: 5082/7213
# https://www.sec.gov/Archives/edgar/data/877212/000162828016011978/a10k12312015zbra.htm
# CIK:877212 Progess: 5083/7213
# https://www.sec.gov/Archives/edgar/data/805305/000162828016010383/zqk_20151031x10-k.htm
# CIK:805305 Progess: 5084/7213
# https://www.sec.gov/Archives/edgar/data/1432939/000154998316000012/crdx-20151231_10k.htm
# CIK:1432939 Progess: 5085/7213
# https://www.sec.gov/Archives/edgar/data/1650132/000165013216000041/fourcorners10-k.htm
# CIK:1650132 Progess: 5086/7213
# https://www.sec.gov/Archives/edgar/data/1023459/000168316816000633/simulations_10k-083116.htm
# CIK:1023459 Progess: 5087/7213
# https://www.sec.gov/Archives/edgar/data/811589/000117494716002230/form10k-15341_fbnc.htm
# CIK:811589 Progess: 5088/7213
# https://www.sec.gov/Archives/edgar/data/1590750/000117184316008702/f10k_032116p.htm
# CIK:1590750 Progess: 5089/7213
# https://www.sec.gov/Archives/edgar/data/91668/000121390016014258/f10k2016_solitrondevices.htm
# CIK:91668 Progess: 5090/7213
# https://www.sec.gov/Archives/edgar/data/311817/000157587216000301/10k.htm
# CIK:311817 Progess: 5091/7213
# https://www.sec.gov/Archives/edgar/data/1092662/000109266216000121/form10_k.htm
# CIK:1092662 Progess: 5092/7213
# https://www.sec.gov/Archives/edgar/data/1142596/000156459016012671/nuva-10k_20151231.htm
# CIK:1142596 Progess: 5093/7213
# None
# CIK 818479: No filing URL found.
# CIK:818479 Progess: 5094/7213
# https://www.sec.gov/Archives/edgar/data/894671/000089467116000060/sec10k123115.htm
# CIK:894671 Progess: 5095/7213
# https://www.sec.gov/Archives/edgar/data/312257/000118518516004093/innovativefood10k123115.htm
# CIK:312257 Progess: 5096/7213
# https://www.sec.gov/Archives/edgar/data/880115/000088011516000052/cwei-123115x10xk.htm
# CIK:880115 Progess: 5097/7213
# None
# CIK 1617049: No filing URL found.
# CIK:1617049 Progess: 5098/7213
# https://www.sec.gov/Archives/edgar/data/72207/000007220716000070/nbl-20151231x10k.htm
# CIK:72207 Progess: 5099/7213
# https://www.sec.gov/Archives/edgar/data/1021604/000117891316004887/zk1618245.htm
# CIK:1021604 Progess: 5100/7213
# https://www.sec.gov/Archives/edgar/data/1008654/000100865416000035/tup10k122615.htm
# CIK:1008654 Progess: 5101/7213
# https://www.sec.gov/Archives/edgar/data/1287213/000155837016003908/plow-20151231x10k.htm
# CIK:1287213 Progess: 5102/7213
# https://www.sec.gov/Archives/edgar/data/1402281/000140228116000077/ern-123115x10k.htm
# CIK:1402281 Progess: 5103/7213
# https://www.sec.gov/Archives/edgar/data/1380846/000138084616000029/tsc-12312015x10k.htm
# CIK:1380846 Progess: 5104/7213
# https://www.sec.gov/Archives/edgar/data/277058/000114420416115237/v444480_10k.htm
# CIK:277058 Progess: 5105/7213
# https://www.sec.gov/Archives/edgar/data/76605/000143774916027616/patk20151231_10k.htm
# CIK:76605 Progess: 5106/7213
# https://www.sec.gov/Archives/edgar/data/1022705/000102270516000054/teso-12312015x10kq4.htm
# CIK:1022705 Progess: 5107/7213
# https://www.sec.gov/Archives/edgar/data/1497645/000110465916099595/a15-23289_110k.htm
# CIK:1497645 Progess: 5108/7213
# https://www.sec.gov/Archives/edgar/data/1615169/000114420416129930/v451405_10k.htm
# CIK:1615169 Progess: 5109/7213
# https://www.sec.gov/Archives/edgar/data/1450973/000114420416112743/v443004_10k.htm
# CIK:1450973 Progess: 5110/7213
# https://www.sec.gov/Archives/edgar/data/1637207/000156459016014027/plnt-10k_20151231.htm
# CIK:1637207 Progess: 5111/7213
# https://www.sec.gov/Archives/edgar/data/768411/000076841116000015/cybe_20151231-10k.htm
# CIK:768411 Progess: 5112/7213
# https://www.sec.gov/Archives/edgar/data/907242/000110465916104448/a15-23305_110k.htm
# CIK:907242 Progess: 5113/7213
# https://www.sec.gov/Archives/edgar/data/908315/000110465916103213/a15-23284_110k.htm
# CIK:908315 Progess: 5114/7213
# https://www.sec.gov/Archives/edgar/data/317788/000162828016017110/apps10-k3312016document.htm
# CIK:317788 Progess: 5115/7213
# https://www.sec.gov/Archives/edgar/data/1362988/000136298816000016/ayrq4201510-k.htm
# CIK:1362988 Progess: 5116/7213
# https://www.sec.gov/Archives/edgar/data/1281774/000162828016012332/a10k-123115.htm
# CIK:1281774 Progess: 5117/7213
# https://www.sec.gov/Archives/edgar/data/1308547/000162828016021559/a10-kfy16.htm
# CIK:1308547 Progess: 5118/7213
# https://www.sec.gov/Archives/edgar/data/40730/000119312516601450/d162429d10k.htm
# CIK:40730 Progess: 5119/7213
# https://www.sec.gov/Archives/edgar/data/831547/000083154716000059/sppi-201510k.htm
# CIK:831547 Progess: 5120/7213
# https://www.sec.gov/Archives/edgar/data/1107421/000119312516475875/d113701d10k.htm
# CIK:1107421 Progess: 5121/7213
# None
# CIK 1581804: No filing URL found.
# CIK:1581804 Progess: 5122/7213
# https://www.sec.gov/Archives/edgar/data/1423586/000121465916010075/b21916010k.htm
# CIK:1423586 Progess: 5123/7213
# https://www.sec.gov/Archives/edgar/data/1597033/000159703316000136/sabr-10k_20151231.htm
# CIK:1597033 Progess: 5124/7213
# https://www.sec.gov/Archives/edgar/data/1490949/000149315216010486/form10-k.htm
# CIK:1490949 Progess: 5125/7213
# None
# CIK 90498: No filing URL found.
# CIK:90498 Progess: 5126/7213
# None
# CIK 825322: No filing URL found.
# CIK:825322 Progess: 5127/7213
# https://www.sec.gov/Archives/edgar/data/729237/000072923716000111/pky-20151231x10k.htm
# CIK:729237 Progess: 5128/7213
# https://www.sec.gov/Archives/edgar/data/13239/000001323916000082/hexion201510k.htm
# CIK:13239 Progess: 5129/7213
# https://www.sec.gov/Archives/edgar/data/277509/000027750916000096/fss10k20151231.htm
# CIK:277509 Progess: 5130/7213
# https://www.sec.gov/Archives/edgar/data/884905/000088490516000108/px201510-k.htm
# CIK:884905 Progess: 5131/7213
# https://www.sec.gov/Archives/edgar/data/1320414/000104746916010467/a2227345z10-k.htm
# CIK:1320414 Progess: 5132/7213
# https://www.sec.gov/Archives/edgar/data/931584/000093158416000009/usap-20151231x10k.htm
# CIK:931584 Progess: 5133/7213
# https://www.sec.gov/Archives/edgar/data/1555995/000155889116000200/jbct-20151231_10k.htm
# CIK:1555995 Progess: 5134/7213
# None
# CIK 1578305: No filing URL found.
# CIK:1578305 Progess: 5135/7213
# https://www.sec.gov/Archives/edgar/data/836809/000165495416002435/aftermaster_10k-16977.htm
# CIK:836809 Progess: 5136/7213
# https://www.sec.gov/Archives/edgar/data/31791/000003179116000014/pki-0103201610k.htm
# CIK:31791 Progess: 5137/7213
# https://www.sec.gov/Archives/edgar/data/872912/000156459016015042/dcth-10k_20151231.htm
# CIK:872912 Progess: 5138/7213
# https://www.sec.gov/Archives/edgar/data/749038/000114420416122127/v447184_10k.htm
# CIK:749038 Progess: 5139/7213
# https://www.sec.gov/Archives/edgar/data/1047881/000143774916028354/taln20151231_10k.htm
# CIK:1047881 Progess: 5140/7213
# https://www.sec.gov/Archives/edgar/data/837010/000083701016000081/vriac2015q410-kreport.htm
# CIK:837010 Progess: 5141/7213
# https://www.sec.gov/Archives/edgar/data/1622676/000154972716000157/txspform10kjune302016.htm
# CIK:1622676 Progess: 5142/7213
# https://www.sec.gov/Archives/edgar/data/1455206/000107878216002391/f10k123115_10k.htm
# CIK:1455206 Progess: 5143/7213
# https://www.sec.gov/Archives/edgar/data/1092699/000119312516476036/d105391d10k.htm
# CIK:1092699 Progess: 5144/7213
# https://www.sec.gov/Archives/edgar/data/1388319/000118518516003859/usstemcell10k123115.htm
# CIK:1388319 Progess: 5145/7213
# https://www.sec.gov/Archives/edgar/data/1017303/000101730316000085/form10k2015.htm
# CIK:1017303 Progess: 5146/7213
# https://www.sec.gov/Archives/edgar/data/1333170/000133317016000025/nxtm20151231-10k.htm
# CIK:1333170 Progess: 5147/7213
# https://www.sec.gov/Archives/edgar/data/732026/000141588916007230/trt10k_jun302016.htm
# CIK:732026 Progess: 5148/7213
# https://www.sec.gov/Archives/edgar/data/104894/000010489416000140/wre10-kx12312015.htm
# CIK:104894 Progess: 5149/7213
# https://www.sec.gov/Archives/edgar/data/887151/000117184316008910/f10k_033016.htm
# CIK:887151 Progess: 5150/7213
# https://www.sec.gov/Archives/edgar/data/1526113/000152611316000014/gnl1231201510-k.htm
# CIK:1526113 Progess: 5151/7213
# https://www.sec.gov/Archives/edgar/data/1166126/000116612616000069/jcp-0130201610k.htm
# CIK:1166126 Progess: 5152/7213
# https://www.sec.gov/Archives/edgar/data/1492691/000149269116000059/swft-10k12312015.htm
# CIK:1492691 Progess: 5153/7213
# https://www.sec.gov/Archives/edgar/data/1421601/000151316216000713/wmtn201510k.htm
# CIK:1421601 Progess: 5154/7213
# https://www.sec.gov/Archives/edgar/data/1432150/000114036116057556/form10k.htm
# CIK:1432150 Progess: 5155/7213
# https://www.sec.gov/Archives/edgar/data/1579910/000157991016000020/resn20151231-10k.htm
# CIK:1579910 Progess: 5156/7213
# https://www.sec.gov/Archives/edgar/data/1594617/000156459016013261/lq-10k_20151231.htm
# CIK:1594617 Progess: 5157/7213
# https://www.sec.gov/Archives/edgar/data/1050007/000105000716000015/nutr-09302016x10k.htm
# CIK:1050007 Progess: 5158/7213
# https://www.sec.gov/Archives/edgar/data/1103090/000154812316000514/reflect10k2015v5.htm
# CIK:1103090 Progess: 5159/7213
# https://www.sec.gov/Archives/edgar/data/902274/000090227416000250/form10-k.htm
# CIK:902274 Progess: 5160/7213
# https://www.sec.gov/Archives/edgar/data/832488/000143774916039131/mamsg20160725_10k.htm
# CIK:832488 Progess: 5161/7213
# https://www.sec.gov/Archives/edgar/data/1488419/000114420416091487/v433096_10k.htm
# CIK:1488419 Progess: 5162/7213
# https://www.sec.gov/Archives/edgar/data/876427/000156276216000396/mnro-20160326x10k.htm
# CIK:876427 Progess: 5163/7213
# https://www.sec.gov/Archives/edgar/data/1641601/000156459016015388/ck0001641601-10k_20151231.htm
# CIK:1641601 Progess: 5164/7213
# https://www.sec.gov/Archives/edgar/data/1532383/000155278116001449/vj12312015.htm
# CIK:1532383 Progess: 5165/7213
# None
# CIK 202058: No filing URL found.
# CIK:202058 Progess: 5166/7213
# None
# CIK 1046102: No filing URL found.
# CIK:1046102 Progess: 5167/7213
# https://www.sec.gov/Archives/edgar/data/1434621/000143462116000052/tree-12312015x10k.htm
# CIK:1434621 Progess: 5168/7213
# https://www.sec.gov/Archives/edgar/data/1637880/000155837016004089/tris-20151231x10k.htm
# CIK:1637880 Progess: 5169/7213
# https://www.sec.gov/Archives/edgar/data/912750/000091275016000053/nfx201510-k.htm
# CIK:912750 Progess: 5170/7213
# https://www.sec.gov/Archives/edgar/data/311094/000117184316008199/f10k_022616p.htm
# CIK:311094 Progess: 5171/7213
# https://www.sec.gov/Archives/edgar/data/1370489/000149315216008361/form10-k.htm
# CIK:1370489 Progess: 5172/7213
# https://www.sec.gov/Archives/edgar/data/91928/000009192816000088/sji-12311510xk.htm
# CIK:91928 Progess: 5173/7213
# https://www.sec.gov/Archives/edgar/data/934739/000157104916013229/t1600740_10k.htm
# CIK:934739 Progess: 5174/7213
# https://www.sec.gov/Archives/edgar/data/1520592/000151116416001039/f10k3312016.htm
# CIK:1520592 Progess: 5175/7213
# None
# CIK 1611742: No filing URL found.
# CIK:1611742 Progess: 5176/7213
# https://www.sec.gov/Archives/edgar/data/1037646/000103764616000043/mtd_10kx12312015.htm
# CIK:1037646 Progess: 5177/7213
# https://www.sec.gov/Archives/edgar/data/714603/000071460316000050/dst10k2015.htm
# CIK:714603 Progess: 5178/7213
# https://www.sec.gov/Archives/edgar/data/1579877/000157987716000199/a20151231-10xkxoutfront.htm
# CIK:1579877 Progess: 5179/7213
# https://www.sec.gov/Archives/edgar/data/1137883/000114420416086932/v432184_10k.htm
# CIK:1137883 Progess: 5180/7213
# https://www.sec.gov/Archives/edgar/data/913165/000156459016014007/exac-10k_20151231.htm
# CIK:913165 Progess: 5181/7213
# https://www.sec.gov/Archives/edgar/data/1644482/000143774916028666/nwbb20151231_10k.htm
# CIK:1644482 Progess: 5182/7213
# https://www.sec.gov/Archives/edgar/data/1562151/000156215116000111/c151-20151231x10k.htm
# CIK:1562151 Progess: 5183/7213
# https://www.sec.gov/Archives/edgar/data/1598981/000072174816001134/sfql10k033016.htm
# CIK:1598981 Progess: 5184/7213
# https://www.sec.gov/Archives/edgar/data/904979/000090497916000048/shlo1031201510-k.htm
# CIK:904979 Progess: 5185/7213
# https://www.sec.gov/Archives/edgar/data/1069878/000119312516472797/d101319d10k.htm
# CIK:1069878 Progess: 5186/7213
# https://www.sec.gov/Archives/edgar/data/758743/000119312516604208/d137464d10k.htm
# CIK:758743 Progess: 5187/7213
# https://www.sec.gov/Archives/edgar/data/1624322/000119312516510912/d124577d10k.htm
# CIK:1624322 Progess: 5188/7213
# https://www.sec.gov/Archives/edgar/data/1437226/000119312516517521/d100964d10k.htm
# CIK:1437226 Progess: 5189/7213
# https://www.sec.gov/Archives/edgar/data/1097396/000119312516519741/d101885d10k.htm
# CIK:1097396 Progess: 5190/7213
# https://www.sec.gov/Archives/edgar/data/928658/000100888616000285/form10k.htm
# CIK:928658 Progess: 5191/7213
# https://www.sec.gov/Archives/edgar/data/1475841/000155837016003670/nbhc-20151231x10k.htm
# CIK:1475841 Progess: 5192/7213
# https://www.sec.gov/Archives/edgar/data/1089819/000108981916000071/cnl-12312015x10k.htm
# CIK:1089819 Progess: 5193/7213
# https://www.sec.gov/Archives/edgar/data/1145197/000114519716000083/podd-2015x12x31_10xk.htm
# CIK:1145197 Progess: 5194/7213
# https://www.sec.gov/Archives/edgar/data/1588238/000158823816000025/riceenergyinc10k-december3.htm
# CIK:1588238 Progess: 5195/7213
# https://www.sec.gov/Archives/edgar/data/1474307/000138713116004694/kmpf-10k_123115.htm
# CIK:1474307 Progess: 5196/7213
# https://www.sec.gov/Archives/edgar/data/1067294/000114036116080733/form10k.htm
# CIK:1067294 Progess: 5197/7213
# https://www.sec.gov/Archives/edgar/data/1081568/000113705016000195/f10k_sep302015filed.htm
# CIK:1081568 Progess: 5198/7213
# https://www.sec.gov/Archives/edgar/data/945764/000094576416000092/dnr-20151231x10k.htm
# CIK:945764 Progess: 5199/7213
# https://www.sec.gov/Archives/edgar/data/1034760/000114420416088207/v433040_10k.htm
# CIK:1034760 Progess: 5200/7213
# https://www.sec.gov/Archives/edgar/data/918543/000154812316000506/castlegroup201510k03242016.htm
# CIK:918543 Progess: 5201/7213
# None
# CIK 55067: No filing URL found.
# CIK:55067 Progess: 5202/7213
# https://www.sec.gov/Archives/edgar/data/1297336/000143774916028591/rloc20151201_10k.htm
# CIK:1297336 Progess: 5203/7213
# https://www.sec.gov/Archives/edgar/data/102037/000010203716000046/uvv-20160331x10k.htm
# CIK:102037 Progess: 5204/7213
# https://www.sec.gov/Archives/edgar/data/1292519/000104746916010780/a2227601z10-k.htm
# CIK:1292519 Progess: 5205/7213
# https://www.sec.gov/Archives/edgar/data/1011835/000156459016013460/mdvn-10k_20151231.htm
# CIK:1011835 Progess: 5206/7213
# None
# CIK 789570: No filing URL found.
# CIK:789570 Progess: 5207/7213
# https://www.sec.gov/Archives/edgar/data/1595262/000156459016012901/ims-10k_20151231.htm
# CIK:1595262 Progess: 5208/7213
# https://www.sec.gov/Archives/edgar/data/704532/000156459016013119/nano-10k_20151226.htm
# CIK:704532 Progess: 5209/7213
# https://www.sec.gov/Archives/edgar/data/318673/000109690616001519/security10k.htm
# CIK:318673 Progess: 5210/7213
# None
# CIK 895728: No filing URL found.
# CIK:895728 Progess: 5211/7213
# None
# CIK 58492: No filing URL found.
# CIK:58492 Progess: 5212/7213
# https://www.sec.gov/Archives/edgar/data/1010612/000119312516485321/d62359d10k.htm
# CIK:1010612 Progess: 5213/7213
# https://www.sec.gov/Archives/edgar/data/1601545/000160154516000123/bluehills10-k2015.htm
# CIK:1601545 Progess: 5214/7213
# https://www.sec.gov/Archives/edgar/data/1289945/000128994516000062/spok-12312015x10k.htm
# CIK:1289945 Progess: 5215/7213
# https://www.sec.gov/Archives/edgar/data/1328143/000155837016003389/adms-20151231x10k.htm
# CIK:1328143 Progess: 5216/7213
# None
# CIK 1077618: No filing URL found.
# CIK:1077618 Progess: 5217/7213
# https://www.sec.gov/Archives/edgar/data/1330849/000133084916000134/a1231201510-k.htm
# CIK:1330849 Progess: 5218/7213
# None
# CIK 912767: No filing URL found.
# CIK:912767 Progess: 5219/7213
# https://www.sec.gov/Archives/edgar/data/1075415/000155837016003411/snh-20151231x10k.htm
# CIK:1075415 Progess: 5220/7213
# https://www.sec.gov/Archives/edgar/data/1043277/000104327716000020/chrw-10k2015.htm
# CIK:1043277 Progess: 5221/7213
# https://www.sec.gov/Archives/edgar/data/1275229/000155837016004056/gmo-20151231x10k.htm
# CIK:1275229 Progess: 5222/7213
# https://www.sec.gov/Archives/edgar/data/1527709/000152770916000075/mcep20151231-10k.htm
# CIK:1527709 Progess: 5223/7213
# https://www.sec.gov/Archives/edgar/data/890319/000089031916000202/tco-123115x10k.htm
# CIK:890319 Progess: 5224/7213
# https://www.sec.gov/Archives/edgar/data/777917/000077791716000315/pruco201510-k.htm
# CIK:777917 Progess: 5225/7213
# None
# CIK 1639691: No filing URL found.
# CIK:1639691 Progess: 5226/7213
# https://www.sec.gov/Archives/edgar/data/825411/000114036116090664/form10k.htm
# CIK:825411 Progess: 5227/7213
# https://www.sec.gov/Archives/edgar/data/1090061/000109006116000050/omn-20151130x10k.htm
# CIK:1090061 Progess: 5228/7213
# https://www.sec.gov/Archives/edgar/data/1547355/000164033416000757/2015dec31-slpc_10k.htm
# CIK:1547355 Progess: 5229/7213
# https://www.sec.gov/Archives/edgar/data/1507385/000150738516000097/vereit1231201510kdoc.htm
# CIK:1507385 Progess: 5230/7213
# https://www.sec.gov/Archives/edgar/data/1537048/000114420416082949/v426625_10k.htm
# CIK:1537048 Progess: 5231/7213
# https://www.sec.gov/Archives/edgar/data/915389/000091538916000095/emn2015123110k.htm
# CIK:915389 Progess: 5232/7213
# https://www.sec.gov/Archives/edgar/data/1320760/000114420416091505/v434265_10k.htm
# CIK:1320760 Progess: 5233/7213
# https://www.sec.gov/Archives/edgar/data/893691/000089369116000072/a2015form10-k.htm
# CIK:893691 Progess: 5234/7213
# None
# CIK 316709: No filing URL found.
# CIK:316709 Progess: 5235/7213
# None
# CIK 1393052: No filing URL found.
# CIK:1393052 Progess: 5236/7213
# https://www.sec.gov/Archives/edgar/data/1137789/000104746916014732/a2229376z10-k.htm
# CIK:1137789 Progess: 5237/7213
# https://www.sec.gov/Archives/edgar/data/1095073/000109507316000071/group10k2015.htm
# CIK:1095073 Progess: 5238/7213
# https://www.sec.gov/Archives/edgar/data/1622231/000147793216013860/emerald_10k.htm
# CIK:1622231 Progess: 5239/7213
# None
# CIK 1109448: No filing URL found.
# CIK:1109448 Progess: 5240/7213
# https://www.sec.gov/Archives/edgar/data/1138118/000119312516484680/d215062d10k.htm
# CIK:1138118 Progess: 5241/7213
# https://www.sec.gov/Archives/edgar/data/1144354/000114435416000129/hpy1231201510kye.htm
# CIK:1144354 Progess: 5242/7213
# https://www.sec.gov/Archives/edgar/data/1460702/000149315216008162/form10-k.htm
# CIK:1460702 Progess: 5243/7213
# https://www.sec.gov/Archives/edgar/data/1277902/000155837016003920/mvbf-20151231x10k.htm
# CIK:1277902 Progess: 5244/7213
# https://www.sec.gov/Archives/edgar/data/98752/000155837016006550/ttlo-20160430x10k.htm
# CIK:98752 Progess: 5245/7213
# https://www.sec.gov/Archives/edgar/data/1326771/000132677116000038/fhlbcin201510-k.htm
# CIK:1326771 Progess: 5246/7213
# https://www.sec.gov/Archives/edgar/data/1100542/000157104916013365/t1600703_10k.htm
# CIK:1100542 Progess: 5247/7213
# https://www.sec.gov/Archives/edgar/data/1428389/000127351116000192/f160331bloxform10k.htm
# CIK:1428389 Progess: 5248/7213
# None
# CIK 1361658: No filing URL found.
# CIK:1361658 Progess: 5249/7213
# https://www.sec.gov/Archives/edgar/data/1029199/000102919916000143/eeft1231201510k.htm
# CIK:1029199 Progess: 5250/7213
# None
# CIK 1336545: No filing URL found.
# CIK:1336545 Progess: 5251/7213
# https://www.sec.gov/Archives/edgar/data/1066605/000162828016012581/hsii-123115x10k.htm
# CIK:1066605 Progess: 5252/7213
# https://www.sec.gov/Archives/edgar/data/1586372/000168316816000318/knowledge_10k-063116.htm
# CIK:1586372 Progess: 5253/7213
# None
# CIK 866121: No filing URL found.
# CIK:866121 Progess: 5254/7213
# https://www.sec.gov/Archives/edgar/data/1177702/000156459016013560/saia-10k_20151231.htm
# CIK:1177702 Progess: 5255/7213
# https://www.sec.gov/Archives/edgar/data/1118037/000114420416088311/v433134_10k.htm
# CIK:1118037 Progess: 5256/7213
# https://www.sec.gov/Archives/edgar/data/1269021/000156459016013714/ptla-10k_20151231.htm
# CIK:1269021 Progess: 5257/7213
# https://www.sec.gov/Archives/edgar/data/1616297/000156459016015522/avnu-10k_20151231.htm
# CIK:1616297 Progess: 5258/7213
# https://www.sec.gov/Archives/edgar/data/944480/000094448016000097/form10k.htm
# CIK:944480 Progess: 5259/7213
# None
# CIK 1357450: No filing URL found.
# CIK:1357450 Progess: 5260/7213
# https://www.sec.gov/Archives/edgar/data/814046/000089262616000411/alp-k20151231.htm
# CIK:814046 Progess: 5261/7213
# https://www.sec.gov/Archives/edgar/data/42682/000119312516501412/d110788d10k.htm
# CIK:42682 Progess: 5262/7213
# https://www.sec.gov/Archives/edgar/data/1057083/000119312516505058/d68635d10k.htm
# CIK:1057083 Progess: 5263/7213
# https://www.sec.gov/Archives/edgar/data/1540947/000154094716000022/eqm1231201510k.htm
# CIK:1540947 Progess: 5264/7213
# https://www.sec.gov/Archives/edgar/data/1612630/000117184316008640/f10k_031716p.htm
# CIK:1612630 Progess: 5265/7213
# https://www.sec.gov/Archives/edgar/data/1628175/000149315216007742/form10-k.htm
# CIK:1628175 Progess: 5266/7213
# https://www.sec.gov/Archives/edgar/data/1316360/000131636016000114/q41510k.htm
# CIK:1316360 Progess: 5267/7213
# https://www.sec.gov/Archives/edgar/data/1331754/000133175416000277/ind10-k123115.htm
# CIK:1331754 Progess: 5268/7213
# https://www.sec.gov/Archives/edgar/data/1421636/000107997416001041/wetm_10k123115.htm
# CIK:1421636 Progess: 5269/7213
# None
# CIK 1039684: No filing URL found.
# CIK:1039684 Progess: 5270/7213
# https://www.sec.gov/Archives/edgar/data/1367859/000136785916000097/czwi-20160930x10k.htm
# CIK:1367859 Progess: 5271/7213
# https://www.sec.gov/Archives/edgar/data/1389170/000114036116055579/form10k.htm
# CIK:1389170 Progess: 5272/7213
# https://www.sec.gov/Archives/edgar/data/100493/000010049316000281/tsn201610kq4.htm
# CIK:100493 Progess: 5273/7213
# https://www.sec.gov/Archives/edgar/data/46129/000110465916103933/a15-23184_110k.htm
# CIK:46129 Progess: 5274/7213
# https://www.sec.gov/Archives/edgar/data/29644/000162828016019746/dci201673110-k.htm
# CIK:29644 Progess: 5275/7213
# https://www.sec.gov/Archives/edgar/data/1308711/000162828016012786/behringerreiti_12312015-10k.htm
# CIK:1308711 Progess: 5276/7213
# https://www.sec.gov/Archives/edgar/data/1094285/000109428516000177/tdy-20160103x10k.htm
# CIK:1094285 Progess: 5277/7213
# https://www.sec.gov/Archives/edgar/data/1161706/000101968716005632/competitive_10k-123115.htm
# CIK:1161706 Progess: 5278/7213
# https://www.sec.gov/Archives/edgar/data/1534675/000114420416105670/v434305_10k.htm
# CIK:1534675 Progess: 5279/7213
# None
# CIK 8670: No filing URL found.
# CIK:8670 Progess: 5280/7213
# https://www.sec.gov/Archives/edgar/data/1629261/000114420416089609/v433384_10k.htm
# CIK:1629261 Progess: 5281/7213
# https://www.sec.gov/Archives/edgar/data/1610466/000156459016013599/shlx-10k_20151231.htm
# CIK:1610466 Progess: 5282/7213
# https://www.sec.gov/Archives/edgar/data/1094348/000156459016014587/matr-10k_20151231.htm
# CIK:1094348 Progess: 5283/7213
# https://www.sec.gov/Archives/edgar/data/1632127/000143774916026995/cabo20151119_10k.htm
# CIK:1632127 Progess: 5284/7213
# https://www.sec.gov/Archives/edgar/data/751978/000119312516496705/d115632d10k.htm
# CIK:751978 Progess: 5285/7213
# https://www.sec.gov/Archives/edgar/data/20212/000002021216000065/chdn2015123110k.htm
# CIK:20212 Progess: 5286/7213
# https://www.sec.gov/Archives/edgar/data/764622/000076462216000087/pnw2015123110-k.htm
# CIK:764622 Progess: 5287/7213
# https://www.sec.gov/Archives/edgar/data/1511737/000151173716000040/ubnt-06302016x10k.htm
# CIK:1511737 Progess: 5288/7213
# https://www.sec.gov/Archives/edgar/data/1484949/000157104916012881/t1600114_10k.htm
# CIK:1484949 Progess: 5289/7213
# https://www.sec.gov/Archives/edgar/data/1502749/000150274916000052/ever-12312015x10k.htm
# CIK:1502749 Progess: 5290/7213
# https://www.sec.gov/Archives/edgar/data/94049/000156459016013219/scl-10k_20151231.htm
# CIK:94049 Progess: 5291/7213
# None
# CIK 1374881: No filing URL found.
# CIK:1374881 Progess: 5292/7213
# https://www.sec.gov/Archives/edgar/data/1556593/000155659316000025/nrz-20151231x10xk.htm
# CIK:1556593 Progess: 5293/7213
# https://www.sec.gov/Archives/edgar/data/216539/000021653916000218/meg-12312015x10k.htm
# CIK:216539 Progess: 5294/7213
# https://www.sec.gov/Archives/edgar/data/1135185/000119312516468116/d32488d10k.htm
# CIK:1135185 Progess: 5295/7213
# https://www.sec.gov/Archives/edgar/data/1108426/000110842616000165/pnm1231201510-k.htm
# CIK:1108426 Progess: 5296/7213
# https://www.sec.gov/Archives/edgar/data/1100412/000110041216000048/a06301610-k.htm
# CIK:1100412 Progess: 5297/7213
# https://www.sec.gov/Archives/edgar/data/1043565/000119312516519598/d101874d10k.htm
# CIK:1043565 Progess: 5298/7213
# https://www.sec.gov/Archives/edgar/data/1375195/000114420416091408/v433530_10k.htm
# CIK:1375195 Progess: 5299/7213
# None
# CIK 1556179: No filing URL found.
# CIK:1556179 Progess: 5300/7213
# https://www.sec.gov/Archives/edgar/data/1115128/000156459016014569/quot-10k_20151231.htm
# CIK:1115128 Progess: 5301/7213
# https://www.sec.gov/Archives/edgar/data/57131/000104746916013932/a2228987z10-k.htm
# CIK:57131 Progess: 5302/7213
# https://www.sec.gov/Archives/edgar/data/751652/000075165216000260/str12311510k.htm
# CIK:751652 Progess: 5303/7213
# https://www.sec.gov/Archives/edgar/data/1430960/000147793216009322/flug_10k.htm
# CIK:1430960 Progess: 5304/7213
# https://www.sec.gov/Archives/edgar/data/1563922/000161577416004441/s102627_10k.htm
# CIK:1563922 Progess: 5305/7213
# None
# CIK 18349: No filing URL found.
# CIK:18349 Progess: 5306/7213
# https://www.sec.gov/Archives/edgar/data/929940/000162828016018906/azpn-20160630x10k.htm
# CIK:929940 Progess: 5307/7213
# None
# CIK 1451514: No filing URL found.
# CIK:1451514 Progess: 5308/7213
# https://www.sec.gov/Archives/edgar/data/1609065/000160906516000054/form10k.htm
# CIK:1609065 Progess: 5309/7213
# https://www.sec.gov/Archives/edgar/data/1364397/000121465916010104/t21716010k.htm
# CIK:1364397 Progess: 5310/7213
# https://www.sec.gov/Archives/edgar/data/1304280/000130428016000077/nvl-0331201610xk.htm
# CIK:1304280 Progess: 5311/7213
# https://www.sec.gov/Archives/edgar/data/1609351/000160935116000020/spark-201510xk.htm
# CIK:1609351 Progess: 5312/7213
# https://www.sec.gov/Archives/edgar/data/1473597/000104746916011435/a2227817z10-k.htm
# CIK:1473597 Progess: 5313/7213
# https://www.sec.gov/Archives/edgar/data/1052100/000104746916010513/a2227358z10-k.htm
# CIK:1052100 Progess: 5314/7213
# None
# CIK 1321710: No filing URL found.
# CIK:1321710 Progess: 5315/7213
# https://www.sec.gov/Archives/edgar/data/354908/000035490816000103/flir-12312015x10k.htm
# CIK:354908 Progess: 5316/7213
# https://www.sec.gov/Archives/edgar/data/920522/000092052216000097/ess-123115x10k.htm
# CIK:920522 Progess: 5317/7213
# None
# CIK 899051: No filing URL found.
# CIK:899051 Progess: 5318/7213
# https://www.sec.gov/Archives/edgar/data/800240/000119312516472490/d82066d10k.htm
# CIK:800240 Progess: 5319/7213
# https://www.sec.gov/Archives/edgar/data/1359931/000117184316008541/f10k_031416p.htm
# CIK:1359931 Progess: 5320/7213
# https://www.sec.gov/Archives/edgar/data/1491675/000149167516000061/a201510kcce.htm
# CIK:1491675 Progess: 5321/7213
# https://www.sec.gov/Archives/edgar/data/1057877/000105787716000209/ida12311510k.htm
# CIK:1057877 Progess: 5322/7213
# https://www.sec.gov/Archives/edgar/data/1568162/000156816216000021/afin1231201510-k.htm
# CIK:1568162 Progess: 5323/7213
# None
# CIK 920148: No filing URL found.
# CIK:920148 Progess: 5324/7213
# None
# CIK 1504222: No filing URL found.
# CIK:1504222 Progess: 5325/7213
# https://www.sec.gov/Archives/edgar/data/11544/000001154416000086/wrb1231201510k.htm
# CIK:11544 Progess: 5326/7213
# https://www.sec.gov/Archives/edgar/data/1040721/000149315216013927/form10-k.htm
# CIK:1040721 Progess: 5327/7213
# https://www.sec.gov/Archives/edgar/data/822416/000082241616000048/a201510-k.htm
# CIK:822416 Progess: 5328/7213
# https://www.sec.gov/Archives/edgar/data/931755/000086874016000092/k214-15.htm
# CIK:931755 Progess: 5329/7213
# None
# CIK 1045810: No filing URL found.
# CIK:1045810 Progess: 5330/7213
# None
# CIK 705432: No filing URL found.
# CIK:705432 Progess: 5331/7213
# https://www.sec.gov/Archives/edgar/data/355948/000138713116006220/rell_10k-052816.htm
# CIK:355948 Progess: 5332/7213
# https://www.sec.gov/Archives/edgar/data/1460235/000146023516000017/pplt-20151231x10k.htm
# CIK:1460235 Progess: 5333/7213
# https://www.sec.gov/Archives/edgar/data/1515317/000101103416000146/magellan_10k.htm
# CIK:1515317 Progess: 5334/7213
# https://www.sec.gov/Archives/edgar/data/1469134/000146913416000157/a122015fcfp10-k.htm
# CIK:1469134 Progess: 5335/7213
# None
# CIK 1467373: No filing URL found.
# CIK:1467373 Progess: 5336/7213
# https://www.sec.gov/Archives/edgar/data/1580670/000158067016000172/lgih12311510k.htm
# CIK:1580670 Progess: 5337/7213
# https://www.sec.gov/Archives/edgar/data/1479247/000114420416087488/v431713_10k.htm
# CIK:1479247 Progess: 5338/7213
# https://www.sec.gov/Archives/edgar/data/1562214/000114420416087258/v430779_10k.htm
# CIK:1562214 Progess: 5339/7213
# https://www.sec.gov/Archives/edgar/data/1263364/000121390016011993/f10k2015_jowayhealth.htm
# CIK:1263364 Progess: 5340/7213
# None
# CIK 92230: No filing URL found.
# CIK:92230 Progess: 5341/7213
# https://www.sec.gov/Archives/edgar/data/50292/000117494716002871/form10k-16246_ieh.htm
# CIK:50292 Progess: 5342/7213
# https://www.sec.gov/Archives/edgar/data/1050743/000117494716002248/form10k-15413_pgfc.htm
# CIK:1050743 Progess: 5343/7213
# https://www.sec.gov/Archives/edgar/data/1034842/000155837016003898/rigl-20151231x10k.htm
# CIK:1034842 Progess: 5344/7213
# https://www.sec.gov/Archives/edgar/data/716006/000071600616000049/yrcw-201510k.htm
# CIK:716006 Progess: 5345/7213
# None
# CIK 1140859: No filing URL found.
# CIK:1140859 Progess: 5346/7213
# https://www.sec.gov/Archives/edgar/data/1255474/000125547416000024/wll-20151231x10k.htm
# CIK:1255474 Progess: 5347/7213
# https://www.sec.gov/Archives/edgar/data/1446714/000114420416085588/v430773_10k.htm
# CIK:1446714 Progess: 5348/7213
# None
# CIK 1035443: No filing URL found.
# CIK:1035443 Progess: 5349/7213
# https://www.sec.gov/Archives/edgar/data/753568/000143774916032955/exar20160331_10k.htm
# CIK:753568 Progess: 5350/7213
# None
# CIK 1492633: No filing URL found.
# CIK:1492633 Progess: 5351/7213
# https://www.sec.gov/Archives/edgar/data/1602658/000156459016014510/istr-10k_20151231.htm
# CIK:1602658 Progess: 5352/7213
# https://www.sec.gov/Archives/edgar/data/1591615/000147793216013812/povd_10k.htm
# CIK:1591615 Progess: 5353/7213
# None
# CIK 1013871: No filing URL found.
# CIK:1013871 Progess: 5354/7213
# https://www.sec.gov/Archives/edgar/data/880771/000088077116000135/scln-20151231x10k.htm
# CIK:880771 Progess: 5355/7213
# https://www.sec.gov/Archives/edgar/data/1081316/000108131616000023/bhe123115form10-kcombined.htm
# CIK:1081316 Progess: 5356/7213
# https://www.sec.gov/Archives/edgar/data/1049502/000119312516481436/d60398d10k.htm
# CIK:1049502 Progess: 5357/7213
# https://www.sec.gov/Archives/edgar/data/1077638/000118518516005212/sensetech10k022916.htm
# CIK:1077638 Progess: 5358/7213
# https://www.sec.gov/Archives/edgar/data/1040426/000119312516482419/d130338d10k.htm
# CIK:1040426 Progess: 5359/7213
# None
# CIK 874015: No filing URL found.
# CIK:874015 Progess: 5360/7213
# https://www.sec.gov/Archives/edgar/data/315189/000104746916017244/a2230400z10-k.htm
# CIK:315189 Progess: 5361/7213
# None
# CIK 1018281: No filing URL found.
# CIK:1018281 Progess: 5362/7213
# https://www.sec.gov/Archives/edgar/data/1489902/000151116416000664/form10k.htm
# CIK:1489902 Progess: 5363/7213
# https://www.sec.gov/Archives/edgar/data/98362/000009836216000097/tkr10k123115.htm
# CIK:98362 Progess: 5364/7213
# https://www.sec.gov/Archives/edgar/data/1015739/000157104916011724/t1600042_10k.htm
# CIK:1015739 Progess: 5365/7213
# https://www.sec.gov/Archives/edgar/data/936528/000093652816000090/wafd930201610k.htm
# CIK:936528 Progess: 5366/7213
# https://www.sec.gov/Archives/edgar/data/1005414/000100541416000080/tru201510k.htm
# CIK:1005414 Progess: 5367/7213
# https://www.sec.gov/Archives/edgar/data/1289636/000109690616001679/profire.htm
# CIK:1289636 Progess: 5368/7213
# https://www.sec.gov/Archives/edgar/data/56978/000005697816000239/a10k2016.htm
# CIK:56978 Progess: 5369/7213
# https://www.sec.gov/Archives/edgar/data/1630430/000107878216002288/f10k113015_10k.htm
# CIK:1630430 Progess: 5370/7213
# https://www.sec.gov/Archives/edgar/data/1357615/000135761516000245/kbr1231201510-k.htm
# CIK:1357615 Progess: 5371/7213
# https://www.sec.gov/Archives/edgar/data/727892/000082002716000170/riversourcelifeinsco12312015.htm
# CIK:727892 Progess: 5372/7213
# https://www.sec.gov/Archives/edgar/data/866439/000101968716005572/klever_10k-123115.htm
# CIK:866439 Progess: 5373/7213
# None
# CIK 721994: No filing URL found.
# CIK:721994 Progess: 5374/7213
# https://www.sec.gov/Archives/edgar/data/730708/000114420416087817/v433074_10k.htm
# CIK:730708 Progess: 5375/7213
# https://www.sec.gov/Archives/edgar/data/1561627/000156459016015146/xone-10k_20151231.htm
# CIK:1561627 Progess: 5376/7213
# https://www.sec.gov/Archives/edgar/data/1385157/000104746916016719/a2230240z10-k.htm
# CIK:1385157 Progess: 5377/7213
# https://www.sec.gov/Archives/edgar/data/1386301/000114420416124557/v448490_10k.htm
# CIK:1386301 Progess: 5378/7213
# https://www.sec.gov/Archives/edgar/data/1186258/000114420416091085/v429269_atel10-10k.htm
# CIK:1186258 Progess: 5379/7213
# https://www.sec.gov/Archives/edgar/data/1512762/000156459016013726/chrs-10k_20151231.htm
# CIK:1512762 Progess: 5380/7213
# https://www.sec.gov/Archives/edgar/data/837919/000083791916000015/everest_10k15.htm
# CIK:837919 Progess: 5381/7213
# None
# CIK 1555280: No filing URL found.
# CIK:1555280 Progess: 5382/7213
# https://www.sec.gov/Archives/edgar/data/1383054/000119312516482730/d32276d10k.htm
# CIK:1383054 Progess: 5383/7213
# https://www.sec.gov/Archives/edgar/data/55135/000005513516000093/kelya-201613x10k.htm
# CIK:55135 Progess: 5384/7213
# https://www.sec.gov/Archives/edgar/data/1113148/000119312516473445/d115525d10k.htm
# CIK:1113148 Progess: 5385/7213
# None
# CIK 707179: No filing URL found.
# CIK:707179 Progess: 5386/7213
# https://www.sec.gov/Archives/edgar/data/1159154/000115915416000178/rjet12311510k.htm
# CIK:1159154 Progess: 5387/7213
# None
# CIK 1401859: No filing URL found.
# CIK:1401859 Progess: 5388/7213
# https://www.sec.gov/Archives/edgar/data/1358190/000121390016011815/f10k2015_orientpaperinc.htm
# CIK:1358190 Progess: 5389/7213
# https://www.sec.gov/Archives/edgar/data/814586/000107261316000724/form10k_17915.htm
# CIK:814586 Progess: 5390/7213
# https://www.sec.gov/Archives/edgar/data/1401564/000093905716000703/ffnw-20151231x10k.htm
# CIK:1401564 Progess: 5391/7213
# https://www.sec.gov/Archives/edgar/data/1024795/000102479516000051/snhy-20160102x10k.htm
# CIK:1024795 Progess: 5392/7213
# https://www.sec.gov/Archives/edgar/data/907045/000155837016006537/ind2-20160331x10k.htm
# CIK:907045 Progess: 5393/7213
# https://www.sec.gov/Archives/edgar/data/1534120/000155837016004299/cerc-20151231x10k.htm
# CIK:1534120 Progess: 5394/7213
# https://www.sec.gov/Archives/edgar/data/1434842/000143484216000069/fes201510k.htm
# CIK:1434842 Progess: 5395/7213
# https://www.sec.gov/Archives/edgar/data/1379714/000137971416000033/splng2015form10-k.htm
# CIK:1379714 Progess: 5396/7213
# https://www.sec.gov/Archives/edgar/data/1364250/000136425016000048/a2015q410-k.htm
# CIK:1364250 Progess: 5397/7213
# https://www.sec.gov/Archives/edgar/data/733590/000138713116004817/tci-10k_123115.htm
# CIK:733590 Progess: 5398/7213
# https://www.sec.gov/Archives/edgar/data/1370880/000162828016011848/feye-2015x10k.htm
# CIK:1370880 Progess: 5399/7213
# https://www.sec.gov/Archives/edgar/data/1626745/000149315216015846/form10-k.htm
# CIK:1626745 Progess: 5400/7213
# https://www.sec.gov/Archives/edgar/data/1076481/000107648116000070/sqnm201510-k.htm
# CIK:1076481 Progess: 5401/7213
# https://www.sec.gov/Archives/edgar/data/1364885/000162828016011138/spr-20151231x10k.htm
# CIK:1364885 Progess: 5402/7213
# https://www.sec.gov/Archives/edgar/data/740663/000143774916027661/flic20151231_10k.htm
# CIK:740663 Progess: 5403/7213
# https://www.sec.gov/Archives/edgar/data/1429260/000114420416088262/v432923_10k.htm
# CIK:1429260 Progess: 5404/7213
# https://www.sec.gov/Archives/edgar/data/903651/000114420416087840/v433526_10k.htm
# CIK:903651 Progess: 5405/7213
# https://www.sec.gov/Archives/edgar/data/72909/000007290916000018/nspw1231201510-k.htm
# CIK:72909 Progess: 5406/7213
# https://www.sec.gov/Archives/edgar/data/19612/000001961216000101/chfc20151231-10xk.htm
# CIK:19612 Progess: 5407/7213
# https://www.sec.gov/Archives/edgar/data/1592058/000119312516501808/d111276d10k.htm
# CIK:1592058 Progess: 5408/7213
# None
# CIK 4904: No filing URL found.
# CIK:4904 Progess: 5409/7213
# https://www.sec.gov/Archives/edgar/data/1016504/000143774916038298/inbp20160819_10k.htm
# CIK:1016504 Progess: 5410/7213
# None
# CIK 1173514: No filing URL found.
# CIK:1173514 Progess: 5411/7213
# https://www.sec.gov/Archives/edgar/data/88121/000155837016003549/seb-20151231x10k.htm
# CIK:88121 Progess: 5412/7213
# https://www.sec.gov/Archives/edgar/data/56047/000114036116054260/form10k.htm
# CIK:56047 Progess: 5413/7213
# https://www.sec.gov/Archives/edgar/data/318346/000147237516000294/form10k.htm
# CIK:318346 Progess: 5414/7213
# https://www.sec.gov/Archives/edgar/data/1575189/000157518916000006/mtch-20151231x10k.htm
# CIK:1575189 Progess: 5415/7213
# https://www.sec.gov/Archives/edgar/data/1141615/000137647416000636/cigf4_10k.htm
# CIK:1141615 Progess: 5416/7213
# https://www.sec.gov/Archives/edgar/data/1493225/000149322516000147/nfbk-20151231x10xk.htm
# CIK:1493225 Progess: 5417/7213
# None
# CIK 1580095: No filing URL found.
# CIK:1580095 Progess: 5418/7213
# https://www.sec.gov/Archives/edgar/data/1512074/000139843216000497/a12865.htm
# CIK:1512074 Progess: 5419/7213
# https://www.sec.gov/Archives/edgar/data/1618563/000161856316000055/nsa-20151231x10k.htm
# CIK:1618563 Progess: 5420/7213
# https://www.sec.gov/Archives/edgar/data/1279715/000121465916010450/w31116110k.htm
# CIK:1279715 Progess: 5421/7213
# https://www.sec.gov/Archives/edgar/data/1603923/000160392316000144/wft201510-k.htm
# CIK:1603923 Progess: 5422/7213
# https://www.sec.gov/Archives/edgar/data/1593034/000159303416000051/endp-12312015x10k.htm
# CIK:1593034 Progess: 5423/7213
# https://www.sec.gov/Archives/edgar/data/1474432/000156459016015322/pstg-10k_20160131.htm
# CIK:1474432 Progess: 5424/7213
# https://www.sec.gov/Archives/edgar/data/1213660/000114420416091133/v434438_10k.htm
# CIK:1213660 Progess: 5425/7213
# https://www.sec.gov/Archives/edgar/data/1064116/000156459016014283/mcccl-10k_20151231.htm
# CIK:1064116 Progess: 5426/7213
# https://www.sec.gov/Archives/edgar/data/1091907/000109190716000046/wwe-20151231x10k.htm
# CIK:1091907 Progess: 5427/7213
# https://www.sec.gov/Archives/edgar/data/700733/000070073316000048/npbc10k2015.htm
# CIK:700733 Progess: 5428/7213
# https://www.sec.gov/Archives/edgar/data/1059262/000162828016012094/sp1231201510-k.htm
# CIK:1059262 Progess: 5429/7213
# https://www.sec.gov/Archives/edgar/data/17843/000001784316000094/crs630201610k.htm
# CIK:17843 Progess: 5430/7213
# https://www.sec.gov/Archives/edgar/data/1616736/000116552716000696/g8175.txt
# CIK:1616736 Progess: 5431/7213
# https://www.sec.gov/Archives/edgar/data/1163609/000116360916000042/sdsp10-k2015.htm
# CIK:1163609 Progess: 5432/7213
# https://www.sec.gov/Archives/edgar/data/720002/000155837016004058/msfg-20151231x10k.htm
# CIK:720002 Progess: 5433/7213
# https://www.sec.gov/Archives/edgar/data/1514732/000151473216000144/a201510-k.htm
# CIK:1514732 Progess: 5434/7213
# https://www.sec.gov/Archives/edgar/data/1488934/000157587216000386/10k.htm
# CIK:1488934 Progess: 5435/7213
# https://www.sec.gov/Archives/edgar/data/1005284/000100528416000136/oled201510-k.htm
# CIK:1005284 Progess: 5436/7213
# https://www.sec.gov/Archives/edgar/data/1642122/000106034916000045/form10k.htm
# CIK:1642122 Progess: 5437/7213
# https://www.sec.gov/Archives/edgar/data/1580883/000107878216003617/f10k063016_10k.htm
# CIK:1580883 Progess: 5438/7213
# https://www.sec.gov/Archives/edgar/data/911216/000165495416002272/ptn_10k.htm
# CIK:911216 Progess: 5439/7213
# https://www.sec.gov/Archives/edgar/data/1470550/000126246316001046/scpd201610k.htm
# CIK:1470550 Progess: 5440/7213
# https://www.sec.gov/Archives/edgar/data/1419951/000161577416004722/s102884_10k.htm
# CIK:1419951 Progess: 5441/7213
# https://www.sec.gov/Archives/edgar/data/1297735/000129773516000038/acep201510-k.htm
# CIK:1297735 Progess: 5442/7213
# https://www.sec.gov/Archives/edgar/data/1609471/000160947116000036/cwi22015q410-k.htm
# CIK:1609471 Progess: 5443/7213
# https://www.sec.gov/Archives/edgar/data/843368/000143774916027312/ncpe20151201_10k.htm
# CIK:843368 Progess: 5444/7213
# https://www.sec.gov/Archives/edgar/data/1065696/000106569616000076/lkq-20151231_10k.htm
# CIK:1065696 Progess: 5445/7213
# https://www.sec.gov/Archives/edgar/data/925263/000119312516519582/d101860d10k.htm
# CIK:925263 Progess: 5446/7213
# https://www.sec.gov/Archives/edgar/data/1411488/000141148816000077/hawk-20160102x10k.htm
# CIK:1411488 Progess: 5447/7213
# https://www.sec.gov/Archives/edgar/data/1579010/000101738616000525/hispanica_2016may31-10k.htm
# CIK:1579010 Progess: 5448/7213
# https://www.sec.gov/Archives/edgar/data/21175/000002117516000135/cna2015q4.htm
# CIK:21175 Progess: 5449/7213
# https://www.sec.gov/Archives/edgar/data/1587523/000158752316000029/knowles20151231-10xk.htm
# CIK:1587523 Progess: 5450/7213
# https://www.sec.gov/Archives/edgar/data/1069183/000106918316000148/a10ktasr123115.htm
# CIK:1069183 Progess: 5451/7213
# https://www.sec.gov/Archives/edgar/data/14846/000001484616000062/brtrealty10-k2016.htm
# CIK:14846 Progess: 5452/7213
# None
# CIK 1274494: No filing URL found.
# CIK:1274494 Progess: 5453/7213
# https://www.sec.gov/Archives/edgar/data/1232524/000123252416000194/jazz1231201510k.htm
# CIK:1232524 Progess: 5454/7213
# https://www.sec.gov/Archives/edgar/data/1355786/000135578616000014/cbnk-20151231x10k.htm
# CIK:1355786 Progess: 5455/7213
# https://www.sec.gov/Archives/edgar/data/892986/000104746916011292/a2227795z10-k.htm
# CIK:892986 Progess: 5456/7213
# None
# ...
# https://www.sec.gov/Archives/edgar/data/1536089/000112785516000810/mascota10k113015.htm
# CIK 1536089: No SIGNATURES section found.
# CIK:1536089 Progess: 7032/7213
# None
# CIK 1675149: No filing URL found.
# CIK:1675149 Progess: 7033/7213
# https://www.sec.gov/Archives/edgar/data/1338929/000101054916000855/gft10k123115.htm
# CIK:1338929 Progess: 7034/7213
# https://www.sec.gov/Archives/edgar/data/1553788/000107997316001203/cms_10k-123115.htm
# CIK:1553788 Progess: 7035/7213
# None
# CIK 1639874: No filing URL found.
# CIK:1639874 Progess: 7036/7213
# None
# CIK 1437352: No filing URL found.
# CIK:1437352 Progess: 7037/7213
# None
# CIK 1672013: No filing URL found.
# CIK:1672013 Progess: 7038/7213
# None
# CIK 1671854: No filing URL found.
# CIK:1671854 Progess: 7039/7213
# https://www.sec.gov/Archives/edgar/data/1484769/000149315216015404/form10-k.htm
# CIK:1484769 Progess: 7040/7213
# https://www.sec.gov/Archives/edgar/data/1388486/000147793216012330/stlt_10k.htm
# CIK:1388486 Progess: 7041/7213
# https://www.sec.gov/Archives/edgar/data/1659183/000164033416002295/go2green_10k.htm
# CIK:1659183 Progess: 7042/7213
# None
# CIK 1676580: No filing URL found.
# CIK:1676580 Progess: 7043/7213
# https://www.sec.gov/Archives/edgar/data/1091596/000114420416129029/v446039_10k.htm
# CIK:1091596 Progess: 7044/7213
# None
# CIK 1673358: No filing URL found.
# CIK:1673358 Progess: 7045/7213
# None
# CIK 1674416: No filing URL found.
# CIK:1674416 Progess: 7046/7213
# https://www.sec.gov/Archives/edgar/data/1503658/000165495416004804/hmus_10k.htm
# CIK:1503658 Progess: 7047/7213
# None
# CIK 1582962: No filing URL found.
# CIK:1582962 Progess: 7048/7213
# https://www.sec.gov/Archives/edgar/data/1532158/000121390016016495/f10k2015_rebelgroupinc.htm
# CIK:1532158 Progess: 7049/7213
# https://www.sec.gov/Archives/edgar/data/1492151/000159406216000651/form10k.htm
# CIK:1492151 Progess: 7050/7213
# https://www.sec.gov/Archives/edgar/data/1643848/000164384816000032/a201610-kxdocument.htm
# CIK:1643848 Progess: 7051/7213
# https://www.sec.gov/Archives/edgar/data/1286345/000128634516000103/hpilhldg-form10kdecember3120.htm
# CIK:1286345 Progess: 7052/7213
# None
# CIK 1566469: No filing URL found.
# CIK:1566469 Progess: 7053/7213
# None
# CIK 1688647: No filing URL found.
# CIK:1688647 Progess: 7054/7213
# None
# CIK 1600694: No filing URL found.
# CIK:1600694 Progess: 7055/7213
# https://www.sec.gov/Archives/edgar/data/1394638/000155335016002847/clcn_10k.htm
# CIK:1394638 Progess: 7056/7213
# None
# CIK 1647513: No filing URL found.
# CIK:1647513 Progess: 7057/7213
# https://www.sec.gov/Archives/edgar/data/1099234/000114420416107375/v441792_10k.htm
# CIK:1099234 Progess: 7058/7213
# https://www.sec.gov/Archives/edgar/data/1599947/000159994716000244/terp201510-k.htm
# CIK:1599947 Progess: 7059/7213
# None
# CIK 1655971: No filing URL found.
# CIK:1655971 Progess: 7060/7213
# https://www.sec.gov/Archives/edgar/data/1478259/000147793216013145/medbook_10k.htm
# CIK:1478259 Progess: 7061/7213
# None
# CIK 1653710: No filing URL found.
# CIK:1653710 Progess: 7062/7213
# https://www.sec.gov/Archives/edgar/data/1281845/000107878216002719/f10k013116_10k.htm
# CIK 1281845: No SIGNATURES section found.
# CIK:1281845 Progess: 7063/7213
# None
# CIK 1651407: No filing URL found.
# CIK:1651407 Progess: 7064/7213
# None
# CIK 1670196: No filing URL found.
# CIK:1670196 Progess: 7065/7213
# None
# CIK 1655020: No filing URL found.
# CIK:1655020 Progess: 7066/7213
# https://www.sec.gov/Archives/edgar/data/1099574/000164033416002061/etbi_10k.htm
# CIK:1099574 Progess: 7067/7213
# None
# CIK 1455684: No filing URL found.
# CIK:1455684 Progess: 7068/7213
# None
# CIK 1498232: No filing URL found.
# CIK:1498232 Progess: 7069/7213
# None
# CIK 1677203: No filing URL found.
# CIK:1677203 Progess: 7070/7213
# https://www.sec.gov/Archives/edgar/data/1066923/000121390016018959/f10k2015_skypeoplefruit.htm
# CIK:1066923 Progess: 7071/7213
# None
# CIK 1390705: No filing URL found.
# CIK:1390705 Progess: 7072/7213
# None
# CIK 1464300: No filing URL found.
# CIK:1464300 Progess: 7073/7213
# None
# CIK 1680966: No filing URL found.
# CIK:1680966 Progess: 7074/7213
# None
# CIK 1533030: No filing URL found.
# CIK:1533030 Progess: 7075/7213
# https://www.sec.gov/Archives/edgar/data/1600438/000104746916014281/a2228977z10-k.htm
# CIK:1600438 Progess: 7076/7213
# None
# CIK 1665300: No filing URL found.
# CIK:1665300 Progess: 7077/7213
# None
# CIK 1618732: No filing URL found.
# CIK:1618732 Progess: 7078/7213
# None
# CIK 1671077: No filing URL found.
# CIK:1671077 Progess: 7079/7213
# https://www.sec.gov/Archives/edgar/data/1394108/000155479516000852/ajgh0414form10k.htm
# CIK:1394108 Progess: 7080/7213
# https://www.sec.gov/Archives/edgar/data/1074458/000152013816001207/hznb-20141231_10k.htm
# CIK:1074458 Progess: 7081/7213
# https://www.sec.gov/Archives/edgar/data/1463959/000121465916014024/dskx_10k.htm
# CIK:1463959 Progess: 7082/7213
# None
# CIK 1678463: No filing URL found.
# CIK:1678463 Progess: 7083/7213
# None
# CIK 1600033: No filing URL found.
# CIK:1600033 Progess: 7084/7213
# None
# CIK 1679629: No filing URL found.
# CIK:1679629 Progess: 7085/7213
# None
# CIK 1654948: No filing URL found.
# CIK:1654948 Progess: 7086/7213
# https://www.sec.gov/Archives/edgar/data/1511161/000139390516001076/askh_10k.htm
# CIK:1511161 Progess: 7087/7213
# None
# CIK 1680228: No filing URL found.
# CIK:1680228 Progess: 7088/7213
# None
# CIK 1614976: No filing URL found.
# CIK:1614976 Progess: 7089/7213
# None
# CIK 1673985: No filing URL found.
# CIK:1673985 Progess: 7090/7213
# None
# CIK 1669162: No filing URL found.
# CIK:1669162 Progess: 7091/7213
# https://www.sec.gov/Archives/edgar/data/90721/000101738616000646/pvsp_2015nov30-10k.htm
# CIK:90721 Progess: 7092/7213
# https://www.sec.gov/Archives/edgar/data/1660690/000166069016000108/vsm10k9302016.htm
# CIK:1660690 Progess: 7093/7213
# None
# CIK 1616314: No filing URL found.
# CIK:1616314 Progess: 7094/7213
# None
# CIK 1680132: No filing URL found.
# CIK:1680132 Progess: 7095/7213
# None
# CIK 1645873: No filing URL found.
# CIK:1645873 Progess: 7096/7213
# None
# CIK 1638058: No filing URL found.
# CIK:1638058 Progess: 7097/7213
# None
# CIK 1427570: No filing URL found.
# CIK:1427570 Progess: 7098/7213
# None
# CIK 1661181: No filing URL found.
# CIK:1661181 Progess: 7099/7213
# https://www.sec.gov/Archives/edgar/data/1662684/000102143216001395/granthill10k123115.txt
# CIK:1662684 Progess: 7100/7213
# None
# CIK 1341766: No filing URL found.
# CIK:1341766 Progess: 7101/7213
# None
# CIK 1676047: No filing URL found.
# CIK:1676047 Progess: 7102/7213
# None
# CIK 1676479: No filing URL found.
# CIK:1676479 Progess: 7103/7213
# None
# CIK 1669779: No filing URL found.
# CIK:1669779 Progess: 7104/7213
# None
# CIK 1385867: No filing URL found.
# CIK:1385867 Progess: 7105/7213
# https://www.sec.gov/Archives/edgar/data/1609472/000152013816001306/ghci-20160930_10k.htm
# CIK:1609472 Progess: 7106/7213
# None
# CIK 1676667: No filing URL found.
# CIK:1676667 Progess: 7107/7213
# None
# CIK 1682593: No filing URL found.
# CIK:1682593 Progess: 7108/7213
# https://www.sec.gov/Archives/edgar/data/1445831/000144583116000007/f10k2014-judo.htm
# CIK:1445831 Progess: 7109/7213
# None
# CIK 1675192: No filing URL found.
# CIK:1675192 Progess: 7110/7213
# https://www.sec.gov/Archives/edgar/data/1525852/000160987616000069/mcig10kdraft83116.htm
# CIK:1525852 Progess: 7111/7213
# https://www.sec.gov/Archives/edgar/data/1669513/000159406216000721/form10k.htm
# CIK:1669513 Progess: 7112/7213
# None
# CIK 1671933: No filing URL found.
# CIK:1671933 Progess: 7113/7213
# https://www.sec.gov/Archives/edgar/data/1655349/000147793216013648/mess_10k.htm
# CIK:1655349 Progess: 7114/7213
# None
# CIK 1646228: No filing URL found.
# CIK:1646228 Progess: 7115/7213
# https://www.sec.gov/Archives/edgar/data/1571759/000121390016018617/f10k2015_ineedmdhold.htm
# CIK:1571759 Progess: 7116/7213
# https://www.sec.gov/Archives/edgar/data/1522767/000126493116000414/worx10k2015.htm
# CIK:1522767 Progess: 7117/7213
# None
# CIK 1666134: No filing URL found.
# CIK:1666134 Progess: 7118/7213
# https://www.sec.gov/Archives/edgar/data/1307969/000160706216000786/bgnn123115form10q.htm
# CIK:1307969 Progess: 7119/7213
# https://www.sec.gov/Archives/edgar/data/1662669/000102143216001398/jacksonhill10k123115.txt
# CIK:1662669 Progess: 7120/7213
# None
# CIK 1656589: No filing URL found.
# CIK:1656589 Progess: 7121/7213
# None
# CIK 1679049: No filing URL found.
# CIK:1679049 Progess: 7122/7213
# None
# CIK 1628738: No filing URL found.
# CIK:1628738 Progess: 7123/7213
# None
# CIK 1662972: No filing URL found.
# CIK:1662972 Progess: 7124/7213
# None
# CIK 1377121: No filing URL found.
# CIK:1377121 Progess: 7125/7213
# https://www.sec.gov/Archives/edgar/data/78311/000109181816000378/soum10062016form10kdec2915.htm
# CIK:78311 Progess: 7126/7213
# None
# CIK 1680048: No filing URL found.
# CIK:1680048 Progess: 7127/7213
# None
# CIK 1561257: No filing URL found.
# CIK:1561257 Progess: 7128/7213
# None
# CIK 1114995: No filing URL found.
# CIK:1114995 Progess: 7129/7213
# https://www.sec.gov/Archives/edgar/data/1582054/000106299316012610/form10k.htm
# CIK:1582054 Progess: 7130/7213
# https://www.sec.gov/Archives/edgar/data/1417172/000114420416141391/v455564_10k.htm
# CIK:1417172 Progess: 7131/7213
# https://www.sec.gov/Archives/edgar/data/1409432/000155116316000527/ngrc105edgarproofv10.htm
# CIK:1409432 Progess: 7132/7213
# None
# CIK 1679426: No filing URL found.
# CIK:1679426 Progess: 7133/7213
# None
# CIK 36377: No filing URL found.
# CIK:36377 Progess: 7134/7213
# None
# CIK 1688316: No filing URL found.
# CIK:1688316 Progess: 7135/7213
# https://www.sec.gov/Archives/edgar/data/1412126/000107878216002629/f10k123114_10k.htm
# CIK:1412126 Progess: 7136/7213
# None
# CIK 1671584: No filing URL found.
# CIK:1671584 Progess: 7137/7213
# https://www.sec.gov/Archives/edgar/data/1326396/000121390016017592/f10k2015_keyuanpetrochem.htm
# CIK:1326396 Progess: 7138/7213
# None
# CIK 1467154: No filing URL found.
# CIK:1467154 Progess: 7139/7213
# https://www.sec.gov/Archives/edgar/data/1658304/000147793216013892/fund_10k.htm
# CIK:1658304 Progess: 7140/7213
# None
# CIK 1663038: No filing URL found.
# CIK:1663038 Progess: 7141/7213
# None
# CIK 1638287: No filing URL found.
# CIK:1638287 Progess: 7142/7213
# None
# CIK 1678536: No filing URL found.
# CIK:1678536 Progess: 7143/7213
# https://www.sec.gov/Archives/edgar/data/1293310/000121465916013550/s82516010k.htm
# CIK:1293310 Progess: 7144/7213
# https://www.sec.gov/Archives/edgar/data/1450390/000120677416007301/bakken3141141-10k.htm
# CIK:1450390 Progess: 7145/7213
# https://www.sec.gov/Archives/edgar/data/1517498/000147793216012793/eworld_10k.htm
# CIK:1517498 Progess: 7146/7213
# None
# CIK 1675820: No filing URL found.
# CIK:1675820 Progess: 7147/7213
# None
# CIK 1679082: No filing URL found.
# CIK:1679082 Progess: 7148/7213
# https://www.sec.gov/Archives/edgar/data/772320/000156459016030523/crxm-10k_20151231.htm
# CIK:772320 Progess: 7149/7213
# https://www.sec.gov/Archives/edgar/data/1584693/000139390516001111/tckf_10k.htm
# CIK:1584693 Progess: 7150/7213
# None
# CIK 1662706: No filing URL found.
# CIK:1662706 Progess: 7151/7213
# None
# CIK 1420520: No filing URL found.
# CIK:1420520 Progess: 7152/7213
# None
# CIK 1679268: No filing URL found.
# CIK:1679268 Progess: 7153/7213
# None
# CIK 1519820: No filing URL found.
# CIK:1519820 Progess: 7154/7213
# https://www.sec.gov/Archives/edgar/data/1309056/000161577416008318/s104645_10k.htm
# CIK:1309056 Progess: 7155/7213
# None
# CIK 1351573: No filing URL found.
# CIK:1351573 Progess: 7156/7213
# None
# CIK 1062579: No filing URL found.
# CIK:1062579 Progess: 7157/7213
# None
# CIK 1422841: No filing URL found.
# CIK:1422841 Progess: 7158/7213
# None
# CIK 1677703: No filing URL found.
# CIK:1677703 Progess: 7159/7213
# https://www.sec.gov/Archives/edgar/data/1659207/000149315216015509/form10-k.htm
# CIK:1659207 Progess: 7160/7213
# None
# CIK 1674227: No filing URL found.
# CIK:1674227 Progess: 7161/7213
# None
# CIK 1378564: No filing URL found.
# CIK:1378564 Progess: 7162/7213
# None
# CIK 1557142: No filing URL found.
# CIK:1557142 Progess: 7163/7213
# None
# CIK 1646188: No filing URL found.
# CIK:1646188 Progess: 7164/7213
# None
# CIK 1615999: No filing URL found.
# CIK:1615999 Progess: 7165/7213
# None
# CIK 1685616: No filing URL found.
# CIK:1685616 Progess: 7166/7213
# https://www.sec.gov/Archives/edgar/data/1534154/000161577416007936/s104047_10k.htm
# CIK:1534154 Progess: 7167/7213
# https://www.sec.gov/Archives/edgar/data/1627041/000149315216015909/form10-k.htm
# CIK:1627041 Progess: 7168/7213
# None
# CIK 1598014: No filing URL found.
# CIK:1598014 Progess: 7169/7213
# None
# CIK 1088213: No filing URL found.
# CIK:1088213 Progess: 7170/7213
# None
# CIK 1681556: No filing URL found.
# CIK:1681556 Progess: 7171/7213
# None
# CIK 1674930: No filing URL found.
# CIK:1674930 Progess: 7172/7213
# None
# CIK 1479239: No filing URL found.
# CIK:1479239 Progess: 7173/7213
# None
# CIK 1682325: No filing URL found.
# CIK:1682325 Progess: 7174/7213
# None
# CIK 1680935: No filing URL found.
# CIK:1680935 Progess: 7175/7213
# None
# CIK 1481512: No filing URL found.
# CIK:1481512 Progess: 7176/7213
# None
# CIK 1678105: No filing URL found.
# CIK:1678105 Progess: 7177/7213
# None
# CIK 1668397: No filing URL found.
# CIK:1668397 Progess: 7178/7213
# https://www.sec.gov/Archives/edgar/data/68589/000075165216000260/str12311510k.htm
# CIK:68589 Progess: 7179/7213
# None
# CIK 1416172: No filing URL found.
# CIK:1416172 Progess: 7180/7213
# None
# CIK 1669812: No filing URL found.
# CIK:1669812 Progess: 7181/7213
# https://www.sec.gov/Archives/edgar/data/1674862/000167486216000008/a9302016ash10k.htm
# CIK:1674862 Progess: 7182/7213
# https://www.sec.gov/Archives/edgar/data/1624025/000101054916000743/hstone10k063016.htm
# CIK:1624025 Progess: 7183/7213
# None
# CIK 1669600: No filing URL found.
# CIK:1669600 Progess: 7184/7213
# https://www.sec.gov/Archives/edgar/data/1522787/000147793216012386/pbfi_10k.htm
# CIK:1522787 Progess: 7185/7213
# None
# CIK 1388658: No filing URL found.
# CIK:1388658 Progess: 7186/7213
# None
# CIK 1027838: No filing URL found.
# CIK:1027838 Progess: 7187/7213
# None
# CIK 1423417: No filing URL found.
# CIK:1423417 Progess: 7188/7213
# None
# CIK 1604191: No filing URL found.
# CIK:1604191 Progess: 7189/7213
# None
# CIK 1272842: No filing URL found.
# CIK:1272842 Progess: 7190/7213
# None
# CIK 1649749: No filing URL found.
# CIK:1649749 Progess: 7191/7213
# None
# CIK 1594555: No filing URL found.
# CIK:1594555 Progess: 7192/7213
# None
# CIK 1625285: No filing URL found.
# CIK:1625285 Progess: 7193/7213
# https://www.sec.gov/Archives/edgar/data/1620702/000162070216000197/glbl201510-k.htm
# CIK:1620702 Progess: 7194/7213
# None
# CIK 1672985: No filing URL found.
# CIK:1672985 Progess: 7195/7213
# None
# CIK 1627480: No filing URL found.
# CIK:1627480 Progess: 7196/7213
# None
# CIK 1683252: No filing URL found.
# CIK:1683252 Progess: 7197/7213
# None
# CIK 1627469: No filing URL found.
# CIK:1627469 Progess: 7198/7213
# None
# CIK 1677761: No filing URL found.
# CIK:1677761 Progess: 7199/7213
# None
# CIK 1419625: No filing URL found.
# CIK:1419625 Progess: 7200/7213
# None
# CIK 1529628: No filing URL found.
# CIK:1529628 Progess: 7201/7213
# None
# CIK 1388410: No filing URL found.
# CIK:1388410 Progess: 7202/7213
# None
# CIK 1653558: No filing URL found.
# CIK:1653558 Progess: 7203/7213
# https://www.sec.gov/Archives/edgar/data/1334126/000147793216012607/gtmm_10k.htm
# CIK:1334126 Progess: 7204/7213
# None
# CIK 1651561: No filing URL found.
# CIK:1651561 Progess: 7205/7213
# None
# CIK 1669811: No filing URL found.
# CIK:1669811 Progess: 7206/7213
# None
# CIK 1438423: No filing URL found.
# CIK:1438423 Progess: 7207/7213
# None
# CIK 1327238: No filing URL found.
# CIK:1327238 Progess: 7208/7213
# None
# CIK 1673475: No filing URL found.
# CIK:1673475 Progess: 7209/7213
# None
# CIK 1679817: No filing URL found.
# CIK:1679817 Progess: 7210/7213
# None
# CIK 1393935: No filing URL found.
# CIK:1393935 Progess: 7211/7213
# None
# CIK 1512228: No filing URL found.
# CIK:1512228 Progess: 7212/7213
# Finish!
#            CIK                         Name
# 0      1169264              STEPHEN C. GRAY
# 1      1169264              ROBERT F. REICH
# 2      1169264        JAMES A. ATTWOOD, JR.
# 3      1169264             TONY G. HOLCOMBE
# 4      1169264          KRISTEN ANKERBRANDT
# ...        ...                          ...
# 39239  1620702                  MARK LERDAL
# 39240  1620702                   FRED BOYLE
# 39241  1334126                Mark A. Luden
# 39242  1334126                Kenneth McCaw
# 39243  1334126  Schneider Downs & Co., Inc.
#
# [39244 rows x 2 columns]

# %% [markdown]
# We next extraced ticker's of companies and combined and cleaned the executives names, cik and tickers.

# %%
sec_url = "https://www.sec.gov/files/company_tickers.json"
headers = {"User-Agent": "YourName/YourCompany your_email@example.com"}
response = requests.get(sec_url, headers=headers)

if response.status_code == 200:
    cik_to_ticker = {str(v["cik_str"]).zfill(10): v["ticker"] for v in response.json().values()}
else:
    cik_to_ticker = {}

sub_data_10K['cik'] = sub_data_10K['cik'].astype(str).str.zfill(10)
sub_data_10K['ticker'] = sub_data_10K['cik'].map(cik_to_ticker).fillna('N/A')
sub_data_10K.head()
# Out:
#           cik                                        name ticker
# 0  0001527541  WHEELER REAL ESTATE INVESTMENT TRUST, INC.  WHLRL
# 1  0001169264                      SYNIVERSE HOLDINGS INC    N/A
# 2  0000712534                        FIRST MERCHANTS CORP  FRMEP
# 3  0001112372        MEDICAL INTERNATIONAL TECHNOLOGY INC    N/A
# 4  0001590565            ASIA EQUITY EXCHANGE GROUP, INC.    N/A

# %%
final_df.head()
# Out:
#        CIK                   Name
# 0  1169264        STEPHEN C. GRAY
# 1  1169264        ROBERT F. REICH
# 2  1169264  JAMES A. ATTWOOD, JR.
# 3  1169264       TONY G. HOLCOMBE
# 4  1169264    KRISTEN ANKERBRANDT

# %%
final_df['CIK'] = final_df['CIK'].astype(str).str.zfill(10)
final_df['Ticker'] = final_df['CIK'].map(cik_to_ticker).fillna('N/A')
final_df.head()
# Out:
#           CIK                   Name Ticker
# 0  0001169264        STEPHEN C. GRAY    N/A
# 1  0001169264        ROBERT F. REICH    N/A
# 2  0001169264  JAMES A. ATTWOOD, JR.    N/A
# 3  0001169264       TONY G. HOLCOMBE    N/A
# 4  0001169264    KRISTEN ANKERBRANDT    N/A

# %%
# Remove rows where Ticker is 'N/A'
final_df_2 = final_df[final_df['Ticker'] != 'N/A'].reset_index(drop=True)
final_df_2
# Out:
#               CIK                 Name Ticker
# 0      0000861884              David H     RS
# 1      0000861884     Gregg J. Mollins     RS
# 2      0000861884       Karla R. Lewis     RS
# 3      0000861884    Sarah J. Anderson     RS
# 4      0000861884     John G. Figueroa     RS
# ...           ...                  ...    ...
# 19061  0001674862      J. Kevin Willis    ASH
# 19062  0001674862   J. William Heitman    ASH
# 19063  0001674862        Peter J. Ganz    ASH
# 19064  0001674862  William A. Wulfsohn    ASH
# 19065  0001674862      J. Kevin Willis    ASH
#
# [19066 rows x 3 columns]

# %%
final_df_2.to_csv('/content/drive/My Drive/final_data.csv', index=False)
from google.colab import files
files.download('/content/drive/My Drive/final_data.csv')

# %%
import pandas as pd

final_df_2 = pd.read_csv('/content/drive/My Drive/final_data.csv')
final_df_2.head()
final_df_3 = final_df_2.head(10)

# %%
from neo4j import GraphDatabase

# Neo4j Connection details
NEO4J_URI = "neo4j+s://254c3ff0.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "BJcjt95hPsvkUSb_7yBZbEEjTftd_EoMS_aoxmeYqYk"

def delete_all_nodes():
    """
    Deletes all nodes and relationships from Neo4j.
    """
    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    try:
        with driver.session() as session:
            session.run("MATCH (n) DETACH DELETE n;")
        print("All nodes and relationships deleted successfully.")
    finally:
        driver.close()

# Call the function to delete all nodes
delete_all_nodes()
# Out:
# All nodes and relationships deleted successfully.

# %% [markdown]
# Created graph with executives and companies nodes

# %%
from neo4j import GraphDatabase
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder \
    .appName("Neo4j Upload") \
    .getOrCreate()

# Convert Pandas DataFrame to Spark DataFrame if needed
final_df_2_spark = spark.createDataFrame(final_df_3)

# Neo4j Connection details
NEO4J_URI = "neo4j+s://254c3ff0.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "BJcjt95hPsvkUSb_7yBZbEEjTftd_EoMS_aoxmeYqYk"

def load_executive_nodes(df):
    """
    Loads unique `Name` values as nodes and connects them to Company nodes.
    """
    def process_partition(partition):
        # Initialize Neo4j driver within the partition function
        driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        try:
            with driver.session() as session:
                for row in partition:
                    cik = row["CIK"]
                    ticker = row["Ticker"]
                    name = row["Name"]

                    # Create Company node with explicit CIK property
                    session.run("""
                    MERGE (c:Company {cik: $cik})
                    SET c.cik = $cik,
                        c.ticker = $ticker

                    MERGE (e:Executive {name: $name})
                    SET e.name = $name

                    MERGE (e)-[:HAS_ROLE]->(c)
                    """, cik=cik, ticker=ticker, name=name)
        finally:
            driver.close()  # Ensure the driver is closed after processing the partition

    df.foreachPartition(process_partition)

load_executive_nodes(final_df_2_spark)

# %% [markdown]
# Fetched top 10 Highly Influential Executives by Degree Centrality and created graph.

# %%
from neo4j import GraphDatabase

# Neo4j Connection
NEO4J_URI = "neo4j+s://254c3ff0.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "BJcjt95hPsvkUSb_7yBZbEEjTftd_EoMS_aoxmeYqYk"

def get_top_companies_by_weighted_degree():
    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    try:
        with driver.session() as session:
            result = session.run("""
            MATCH (e:Executive)-[:HAS_ROLE]->(c:Company)
            WITH e, c, COUNT(c) AS exec_degree
            SET e.degree = exec_degree

            WITH c, SUM(e.degree) AS weighted_degree
            SET c.weighted_degree = weighted_degree
            RETURN c.cik AS cik, c.ticker AS ticker, c.weighted_degree AS weighted_degree
            ORDER BY weighted_degree DESC
            LIMIT 10;
            """)

            print("Top 10 Companies by Weighted Executive Degree Centrality:")
            for record in result:
                print(f"CIK: {record['cik']}, Ticker: {record['ticker']}, Weighted Degree: {record['weighted_degree']}")
    finally:
        driver.close()

# Run the function
get_top_companies_by_weighted_degree()
# Out:
# Top 10 Companies by Weighted Executive Degree Centrality:
# CIK: 898171, Ticker: UWHR, Weighted Degree: 21
# CIK: 1604028, Ticker: WMS, Weighted Degree: 20
# CIK: 1265131, Ticker: HTH, Weighted Degree: 19
# CIK: 27904, Ticker: DAL, Weighted Degree: 19
# CIK: 14693, Ticker: BF-B, Weighted Degree: 18
# CIK: 845877, Ticker: AGM-PG, Weighted Degree: 18
# CIK: 1214816, Ticker: AXS-PE, Weighted Degree: 17
# CIK: 1163609, Ticker: SDSYA, Weighted Degree: 17
# CIK: 1506307, Ticker: EP-PC, Weighted Degree: 17
# CIK: 354707, Ticker: HE, Weighted Degree: 17

# %%
from neo4j import GraphDatabase

# Neo4j Connection
NEO4J_URI = "neo4j+s://254c3ff0.databases.neo4j.io"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "BJcjt95hPsvkUSb_7yBZbEEjTftd_EoMS_aoxmeYqYk"

def get_highly_influential_executives():
    driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    try:
        with driver.session() as session:
            # Run the degree centrality query for executives
            result = session.run("""
            MATCH (e:Executive)-[:HAS_ROLE]->(c:Company)
            WITH e, COUNT(c) AS degree
            SET e.degree = degree

            RETURN e.name AS name, e.degree AS degree
            ORDER BY e.degree DESC
            LIMIT 10;
            """)

            print("Top 10 Highly Influential Executives by Degree Centrality:")
            for record in result:
                print(f"Name: {record['name']}, Degree: {record['degree']}")
    finally:
        driver.close()

# Run the function
get_highly_influential_executives()
# Out:
# Top 10 Highly Influential Executives by Degree Centrality:
# Name: Peter M. Robinson, Degree: 6
# Name: Malcolm R. Fobes III, Degree: 6
# Name: Melinda Gerber, Degree: 6
# Name: Nicholas D. Gerber, Degree: 6
# Name: Gordon L. Ellis, Degree: 6
# Name: Andrew Ngim, Degree: 5
# Name: Stuart Crumbaugh, Degree: 5
# Name: John P. Love, Degree: 5
# Name: Robert L. Nguyen, Degree: 5
# Name: Graham Tuckwell, Degree: 5

# %%
from yfiles_jupyter_graphs_for_neo4j import Neo4jGraphWidget
driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))

g = Neo4jGraphWidget(driver)

def show_graph(driver):
    query = """
    MATCH (c)<-[r:HAS_ROLE]-(e)
    RETURN c, r, e
    LIMIT 100
    """
    g.show_cypher(query)

show_graph(driver)
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
from google.colab import output
output.disable_custom_widget_manager()
